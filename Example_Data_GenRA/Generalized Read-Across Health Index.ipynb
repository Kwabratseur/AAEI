# %%
import pandas as pd
from datetime import datetime
import csv, random, re, math
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
pd.options.plotting.backend = "plotly"
sn.set(rc = {'figure.figsize':(20,10)})
plt.rcParams["figure.figsize"] = (20,10)

# %%
def translateEntry(df,metaData,chemName,DEBUG=False):
    Entry = re.split(" |=",df[chemName])
    #EffectName = df["preferred name"].split(":")
    EffectName = [df["preferred name"][:3], df["preferred name"][3:]]
    Effect = [Entry[1],int(Entry[3])] # Effect that is being indexed, positive 1 or negative (not present) 0
    Mag = float(Entry[4][1:][:-1]) # magnitude of effect compared to nearest neighbours (other columns)
    AUC = float(Entry[6]) # Area Under Curve, measure for accuracy
    p_Val = float(Entry[8]) # p-value, confidence interval. Lower is better
    EffectName.append(int(Entry[3]))
    EffectName.append(Mag)
    EffectName.append(AUC)
    EffectName.append(p_Val)
    df.drop(chemName)
    if DEBUG:
        print(EffectName)
        print(Entry)
        print("--** Effect:{} -- Mag:{} -- AUC:{} -- P-Value:{} **--".format(Effect, Mag, AUC, p_Val))
    thresholdSimilarityVector = []
    thresholdSimilaritySum = 0
    for i,x in enumerate(df[2:]):
        mgkgday = re.findall('\d*\.?\d+',x) # Filter out thresholds in mg/kg/day (I assume mg compound to kg body weight per day)
        if len(mgkgday) ==  0: # no number detected
            mgkgday = 0.0
        else:
            mgkgday = float(mgkgday[0])
        mgkgday /= float(metaData.iloc[2][i+2]) # divide by similarity index; higher similarity means chemical/toxilogical fingerprint is more similar. Range will be bigger if more uncertainty
        thresholdSimilarityVector.append(mgkgday)
        thresholdSimilaritySum += mgkgday*Mag
    thresholdSimilarityVector.append(thresholdSimilaritySum)
    if DEBUG:
        display(thresholdSimilarityVector)
    return EffectName+thresholdSimilarityVector
    
def computeHealthIndex(fileName,DEBUG=False):
    genRAData = pd.read_csv("{}.csv".format(fileName), header=1)
    metaData = genRAData[:3]
    chemName = metaData.columns[1]
    genRAData = genRAData[3:]
    if DEBUG:
        print(metaData)
        print("Test translation:")
        translateEntry(genRAData.iloc[0],metaData,chemName,DEBUG=DEBUG)
        print(translateEntry(genRAData.iloc[random.randrange(len(genRAData))],metaData,chemName,DEBUG=DEBUG))
    healthIndexData = []
    effectLabels = []
    targetLabels = []
    for i in genRAData.iloc:
        healthIndexData.append(translateEntry(i,metaData,chemName))
        effectLabels.append(healthIndexData[-1][0])
        targetLabels.append(healthIndexData[-1][1])
    return healthIndexData ,list(set(effectLabels)), list(set(targetLabels)), metaData, chemName

# %%
def plotResult(table, df, FileNames):
    chemicals = []
    for i in FileNames:
        chemicals.append(i.split("_")[1])
    sn.heatmap(table, linewidths=.0).figure.savefig('Heatmap_All.png')
    
    fig = go.Figure(go.Bar(y=df[df.Formula == chemicals[0]]["positive targets decimal"].values, x=df[df.Formula == chemicals[0]]["Effectgroup"].values, text=chemicals[0]))
    for i in chemicals[1:]:
        fig.add_trace(go.Bar(y=df[df.Formula == i]["positive targets decimal"].values, x=df[df.Formula == i]["Effectgroup"], name=i))
    #fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(height=800, width=3000,uniformtext_minsize=8, uniformtext_mode='hide', barmode='stack', xaxis={'categoryorder':'total descending'})
    fig.write_image("Chemicals-Effectgroup_bar.png")
    fig.show()


    TargetEffectLabels
    fig = go.Figure(go.Bar(y=df[df.Testgroup == TargetEffectLabels[0][0]]["positive targets decimal"].values, x=df[df.Testgroup == TargetEffectLabels[0][0]]["Effectgroup"].values, text=TargetEffectLabels[0][0]))
    for i in TargetEffectLabels[1:]:
        fig.add_trace(go.Bar(y=df[df.Testgroup == i[0]]["positive targets decimal"].values, x=df[df.Testgroup == i[0]]["Effectgroup"], name=i[0]))
    #fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(height=800, width=3000,uniformtext_minsize=8, uniformtext_mode='hide', barmode='stack', xaxis={'categoryorder':'total descending'})
    fig.write_image("Testgroup-Effectgroup_bar.png")
    fig.show()



    fig = go.Figure(data=go.Scatter3d(
        x=df["Effectgroup"],
        y=df["Formula"],
        z=df['Testgroup'],
        text=df['positive targets decimal'],
        mode='markers',
        marker=dict(
            sizemode='diameter',
            sizeref=0.5,
            size=df['positive targets decimal'],
            color = df['total targets'],
            colorscale = 'Viridis',
            colorbar_title = 'decimal<br>targets',
            line_color='rgb(140, 140, 170)'
        )
    ))
    fig.update_layout(height=1000, width=2000,title='Effectgroup Vs testgroup Vs chemical, size denotes sum of positive targets, color denotes amount of targets')
    fig.write_image("3D_plot.png")
    fig.show()



    fig = go.Figure(go.Histogram2d(
            x=df["Effectgroup"],
            y=df["positive targets decimal"]
        ))
    fig.update_layout(height=1600, width=1600)
    fig.write_image("Effectgroup_score.png")
    fig.show()
    fig = go.Figure(go.Histogram2d(
            x=df["Testgroup"],
            y=df["positive targets decimal"]
        ))
    fig.write_image("Testgroup_score.png")
    fig.show()
    fig = go.Figure(go.Histogram2d(
            x=df["Formula"],
            y=df["positive targets decimal"]
        ))
    fig.write_image("Chemical_score.png")
    fig.show()

# %%
def df_normalize(df):
    return df/df.max()

TargetEffectLabels = [["MGR"],["REP"],["DEV"],["CHR"],["SUB"],["SAC"]]
def TrackTargetEffectLabels(HID,Labels):
    for i in HID:
        for j,x in enumerate(Labels):
            if i[0] == x[0]:
                Labels[j].append(i[1][1:])
    for i,x in enumerate(Labels):
        TestType = x[0]
        x.remove(TestType)
        x.sort()
        Labels[i] = [TestType]+list(set(x))
    return Labels

def metaDataGenEffects(effectLabels, HID):
    metaDataHID = []
    for i,x in enumerate(effectLabels):
        Labs = [0,0,0,0,0]
        for j,y in enumerate(HID):
            if x == y[0]: # Is labeled similar
                Labs[0] += 1
                Labs[1] += y[2]
                Labs[2] += y[3]
                Labs[3] += y[-1]
                Labs[4]  = y[0]
        metaDataHID.append(Labs)
    return metaDataHID

def metaDataGenTargets(targetLabels, HID):
    metaDataHID = []
    for i,x in enumerate(targetLabels):
        Labs = [0,0,0,0,0,0]
        for j,y in enumerate(HID):
            if x == y[1]: # Is labeled similar
                Labs[0] += 1
                Labs[1] += y[2]
                Labs[2] += y[3]
                Labs[3] += y[-1]
                Labs[4]  = y[1]
                Labs[5]  = y[0] # But save testgroup data! so we get a very complete dataset :).
        metaDataHID.append(Labs)
    return metaDataHID

def metaDataReport(effectLabels,metaDataHID,md,label):
    display(md)
    FileName = "{}_{}_metadata.csv".format(label,md.columns[1])
    md.to_csv(FileName)
    Header = ["Effectgroup","total targets", "positive targets", "positive targets decimal", "weighted and averaged limit [mg/kg/day]"]
    with open(FileName, 'a', newline='') as f:
        Writer = csv.writer(f)
        Writer.writerow(Header)
        for i, x in enumerate(effectLabels):
            print("{} - total targets: {} - Targets positive: {} - Total targets decimal: {:.2f} - weighted and averaged limit {:.2f} [mg/kg/day]".format(x,metaDataHID[i][0],metaDataHID[i][1],metaDataHID[i][2],metaDataHID[i][3]))
            Writer.writerow([x]+metaDataHID[i])
        f.close()



def BatchReport(fileNames, fileName, fcn="sum", Viz = False):
    Header = ["Formula","Name","total targets", "positive targets", "positive targets decimal", "weighted and averaged limit [mg/kg/day]","Effectgroup"]
    TargetEffectLabels = [["MGR"],["REP"],["DEV"],["CHR"],["SUB"],["SAC"]]
    MetaBlobs = []
    analogBlobs = []
    TargetBlobs = []
    compoundNames = []
    for label in fileNames:
        #label = "genra_O3"
        HID, effectLabels, targetLabels, md, Compound = computeHealthIndex(label)#Ozone
        compoundNames.append(Compound)
        metaDataHID = metaDataGenEffects(effectLabels, HID)
        metaDataHIDt = metaDataGenTargets(targetLabels,HID)
        metaDataReport(effectLabels,metaDataHID,md,label)
        TargetEffectLabels = TrackTargetEffectLabels(HID,TargetEffectLabels)
        TargetBlobs.append(metaDataHIDt)
        MetaBlobs.append(metaDataHID)
        analogBlobs.append(md)
    
    with open("{}_Meta.csv".format(fileName), "w", newline='') as f:
        Writer = csv.writer(f)
        Writer.writerow(Header)
        for i,Blob in enumerate(MetaBlobs):
            for lines in Blob:
                print(lines)
                Writer.writerow([fileNames[i].split("_")[1],compoundNames[i]]+lines)
        f.close()
        
    with open("{}_Target.csv".format(fileName), "w", newline='') as f:
        Writer = csv.writer(f)
        Header.append("Testgroup")
        Writer.writerow(Header)
        for i,Blob in enumerate(TargetBlobs):
            for lines in Blob:
                print(lines)
                Writer.writerow([fileNames[i].split("_")[1],compoundNames[i]]+lines)
        f.close()
    df = pd.read_csv("Batch_Report_Target.csv")#Read the just made file back into DF to use pivottables
    nan_value = float("NaN")
    df.replace("", nan_value, inplace=True)
    df.replace(nan_value, 0,  inplace=True)

    if fcn == "sum":
        table = pd.pivot_table(df, values='positive targets decimal', index=['Effectgroup'],columns=['Formula',"Testgroup"], aggfunc=np.sum)
    elif fcn == "average":
        table = pd.pivot_table(df, values='positive targets decimal', index=['Effectgroup'],columns=['Formula',"Testgroup"], aggfunc=np.average)
    else:
        table = pd.pivot_table(df, values='positive targets decimal', index=['Effectgroup'],columns=['Formula',"Testgroup"], aggfunc=np.mean)
    table.replace("", nan_value, inplace=True)
    table.replace(nan_value, 0,  inplace=True)
    table = df_normalize(table)
    table.to_csv("AEI_Norm_Test.csv")
    if Viz:
         plotResult(table, df, fileNames)
    return MetaBlobs, TargetBlobs, analogBlobs, table, df

# %%
fileNames = ["genra_O3","genra_C10H16O2","genra_C8H14O","genra_CH3CHO","genra_C10H16","genra_N2","genra_CO2","genra_CH2O"]
compoundNames = ["Ozone","3-Isopropenyl-6-oxo-heptanal","6-Methyl-5-hepten-2-one","Acetaldehyde","D-Limonene","Nitrogen","Carbon dioxide","Formaldehyde"]
FileName = "Batch_Report"
MetaBlobs, TargetBlobs, analogBlobs, PVTable, target_DF = BatchReport(fileNames,FileName)
# Out:
#      preferred name          Ozone       Sodium nitrite    Barium metaborate  \
# 0        dsstox_sid  DTXSID0021098        DTXSID0020941        DTXSID1034347
# 1  molecular weight         47.997               68.995              222.940
# 2        similarity        1.00001  0.18181818181818182  0.18181818181818182
#
#     Trisodium arsenate       Silver nitrate Monosodium methanearsonate  \
# 0        DTXSID9039367        DTXSID3032042              DTXSID2025686
# 1              207.887              169.872                    161.951
# 2  0.18181818181818182  0.18181818181818182        0.13333333333333333
#
#   Potassium dichromate Trichloronitromethane Sodium dichromate dihydrate  \
# 0        DTXSID5025948         DTXSID0020315               DTXSID6032061
# 1              294.182               164.370                     297.995
# 2  0.13333333333333333   0.13333333333333333                       0.125
#
#   Sodium fluoroacetate Sodium trichloroacetate  \
# 0        DTXSID8024311           DTXSID6034924
# 1              100.024                 185.360
# 2                0.125                   0.125
#
#   Butanedioic acid, 2,3-dihydroxy- (2R,3R)-, sodium salt (1:2)  \
# 0                                      DTXSID2057861
# 1                                            194.050
# 2                                0.11764705882352941
#
#   Tetrakis(hydroxymethyl)phosphonium sulfate              Silica  \
# 0                              DTXSID0021331       DTXSID1029677
# 1                                    406.280              60.083
# 2                         0.1111111111111111  0.1111111111111111
#
#   Lithium hypochlorite 2-(Hydroxymethyl)-2-nitro-1,3-propanediol
# 0        DTXSID1034688                             DTXSID8027034
# 1               58.390                                   151.118
# 2   0.1111111111111111                       0.10526315789473684
# MGR - total targets: 55 - Targets positive: 12 - Total targets decimal: 8.50 - weighted and averaged limit 3469.12 [mg/kg/day]
# DEV - total targets: 48 - Targets positive: 23 - Total targets decimal: 23.50 - weighted and averaged limit 87704.35 [mg/kg/day]
# SAC - total targets: 74 - Targets positive: 18 - Total targets decimal: 17.10 - weighted and averaged limit 94654.44 [mg/kg/day]
# CHR - total targets: 78 - Targets positive: 24 - Total targets decimal: 27.83 - weighted and averaged limit 9685.57 [mg/kg/day]
# SUB - total targets: 92 - Targets positive: 32 - Total targets decimal: 33.75 - weighted and averaged limit 84568.61 [mg/kg/day]
#      preferred name 3-Isopropenyl-6-oxo-heptanal  \
# 0        dsstox_sid               DTXSID40874121
# 1  molecular weight                      168.236
# 2        similarity                      1.00001
#
#   4-(4-Hydroxyphenyl)butan-2-one 2-Ethylhexanoic acid       Methacrylamide  \
# 0                  DTXSID5044495        DTXSID9025293        DTXSID8029600
# 1                        164.204              144.214               85.106
# 2             0.2127659574468085  0.20930232558139536  0.20588235294117646
#
#                Myrcene       Ethyl acrylate 3,7-Dimethyl-2,6-octadienal  \
# 0        DTXSID6025692        DTXSID4020583               DTXSID6024836
# 1              136.238              100.117                     152.237
# 2  0.17777777777777778  0.17073170731707318          0.1702127659574468
#
#   Tetraacetylethylenediamine      Acetamide  \
# 0              DTXSID5040752  DTXSID7020005
# 1                    228.248         59.068
# 2        0.15789473684210525        0.15625
#
#   Ethylene glycol monoethyl ether acetate           Daminozide  \
# 0                           DTXSID9021928        DTXSID9020370
# 1                                 132.159              160.173
# 2                     0.15555555555555556  0.15217391304347827
#
#   Bis(2-ethylhexyl)hexanedioate           Acrylamide    Methacrylonitrile  \
# 0                 DTXSID0020606        DTXSID5020027        DTXSID1024176
# 1                       370.574               71.079               67.091
# 2           0.14285714285714285  0.14285714285714285  0.14285714285714285
#
#   N,N'-Methylenebisacrylamide Glufosinate-ammonium
# 0               DTXSID8025595        DTXSID1024120
# 1                     154.169              198.159
# 2         0.14285714285714285                 0.14
# MGR - total targets: 53 - Targets positive: 4 - Total targets decimal: 4.00 - weighted and averaged limit 560.00 [mg/kg/day]
# DEV - total targets: 55 - Targets positive: 29 - Total targets decimal: 31.15 - weighted and averaged limit 105303.36 [mg/kg/day]
# SAC - total targets: 43 - Targets positive: 3 - Total targets decimal: 3.00 - weighted and averaged limit 61250.00 [mg/kg/day]
# REP - total targets: 34 - Targets positive: 10 - Total targets decimal: 10.00 - weighted and averaged limit 47812.50 [mg/kg/day]
# CHR - total targets: 60 - Targets positive: 5 - Total targets decimal: 8.60 - weighted and averaged limit 47705.15 [mg/kg/day]
# SUB - total targets: 86 - Targets positive: 18 - Total targets decimal: 23.10 - weighted and averaged limit 180007.59 [mg/kg/day]
#      preferred name 6-Methyl-5-hepten-2-one 3,7-Dimethyl-2,6-octadienal  \
# 0        dsstox_sid           DTXSID5021629               DTXSID6024836
# 1  molecular weight                 126.199                     152.237
# 2        similarity                 1.00001                      0.4375
#
#                Myrcene 4-(4-Hydroxyphenyl)butan-2-one Ethyl acrylate  \
# 0        DTXSID6025692                  DTXSID5044495  DTXSID4020583
# 1              136.238                        164.204        100.117
# 2  0.41935483870967744            0.23076923076923078        0.21875
#
#              Acetamide   tert-Butyl acetate             Urethane  \
# 0        DTXSID7020005        DTXSID1022055        DTXSID9021427
# 1               59.068              116.160               89.094
# 2  0.21739130434782608  0.21428571428571427  0.20689655172413793
#
#   Tetraacetylethylenediamine Ethylene glycol monoethyl ether acetate  \
# 0              DTXSID5040752                           DTXSID9021928
# 1                    228.248                                 132.159
# 2        0.20689655172413793                     0.19444444444444445
#
#         Methacrylamide 1,4-Bis(bromoacetoxy)-2-butene 2-Ethylhexanoic acid  \
# 0        DTXSID8029600                  DTXSID0034308        DTXSID9025293
# 1               85.106                        329.972              144.214
# 2  0.18518518518518517            0.16666666666666666  0.16216216216216217
#
#      Fosamine ammonium  Butyraldehyde oxime  Glycolic acid
# 0        DTXSID9032406        DTXSID2024664  DTXSID0025363
# 1              170.105               87.122         76.051
# 2  0.16216216216216217  0.16129032258064516           0.16
# SUB - total targets: 92 - Targets positive: 31 - Total targets decimal: 33.06 - weighted and averaged limit 217667.05 [mg/kg/day]
# REP - total targets: 34 - Targets positive: 10 - Total targets decimal: 10.00 - weighted and averaged limit 20269.23 [mg/kg/day]
# CHR - total targets: 56 - Targets positive: 6 - Total targets decimal: 7.75 - weighted and averaged limit 12210.22 [mg/kg/day]
# DEV - total targets: 58 - Targets positive: 34 - Total targets decimal: 34.75 - weighted and averaged limit 83943.22 [mg/kg/day]
#      preferred name   Acetaldehyde N,N-Dimethylformamide           Formamide  \
# 0        dsstox_sid  DTXSID5039224         DTXSID6020515       DTXSID8025337
# 1  molecular weight         44.053                73.095              45.041
# 2        similarity        1.00001   0.36363636363636365  0.3333333333333333
#
#   Glutaraldehyde 2E,4E-Hexadienoic acid Dimethylarsinic acid  \
# 0  DTXSID6025355          DTXSID3021277        DTXSID7020508
# 1        100.117                112.128              137.998
# 2            0.2    0.19047619047619047  0.16666666666666666
#
#              Acetamide 1,2-Benzenedicarboxaldehyde N-Nitrosodimethylamine  \
# 0        DTXSID7020005               DTXSID6032514          DTXSID7021029
# 1               59.068                     134.134                 74.083
# 2  0.16666666666666666         0.15789473684210525    0.15384615384615385
#
#     Benzaldehyde 3,7-Dimethyl-2,6-octadienal  \
# 0  DTXSID8039241               DTXSID6024836
# 1        106.124                     152.237
# 2           0.15         0.14285714285714285
#
#   N,N'-Bis(1-formamido-2,2,2-trichloroethyl)piperazine Dimethyl phosphonate  \
# 0                                      DTXSID5032654          DTXSID5020493
# 1                                            434.950                110.049
# 2                                0.14285714285714285    0.14285714285714285
#
#   Methyl methanesulfonate       Ethyl acrylate Monosodium methanearsonate
# 0           DTXSID7020845        DTXSID4020583              DTXSID2025686
# 1                 110.130              100.117                    161.951
# 2     0.14285714285714285  0.13636363636363635        0.13333333333333333
# MGR - total targets: 59 - Targets positive: 17 - Total targets decimal: 16.88 - weighted and averaged limit 42238.87 [mg/kg/day]
# DEV - total targets: 42 - Targets positive: 18 - Total targets decimal: 19.23 - weighted and averaged limit 37290.56 [mg/kg/day]
# SAC - total targets: 51 - Targets positive: 6 - Total targets decimal: 8.11 - weighted and averaged limit 859.23 [mg/kg/day]
# REP - total targets: 33 - Targets positive: 4 - Total targets decimal: 4.96 - weighted and averaged limit 284.18 [mg/kg/day]
# CHR - total targets: 77 - Targets positive: 22 - Total targets decimal: 26.60 - weighted and averaged limit 92372.02 [mg/kg/day]
# SUB - total targets: 93 - Targets positive: 33 - Total targets decimal: 37.01 - weighted and averaged limit 165337.13 [mg/kg/day]
#      preferred name     D-Limonene       Limonene       R-(+)-Pulegone  \
# 0        dsstox_sid  DTXSID1020778  DTXSID2029612        DTXSID2025975
# 1  molecular weight        136.238        136.238              152.237
# 2        similarity        1.00001              1  0.16666666666666666
#
#   alpha-Isomethylionone 1-trans-delta-9-Tetrahydrocannabinol  \
# 0         DTXSID7027047                        DTXSID6021327
# 1               206.329                              314.469
# 2   0.15789473684210525                                 0.15
#
#      Methacrylonitrile       Methacrylamide     Trinexapac-ethyl  \
# 0        DTXSID1024176        DTXSID8029600        DTXSID9032535
# 1               67.091               85.106              252.266
# 2  0.14705882352941177  0.14285714285714285  0.14035087719298245
#
#   4-Chloro-3-methylphenol Prohexadione-calcium           Isophorone  \
# 0           DTXSID4021717        DTXSID9034496        DTXSID8020759
# 1                 142.580              250.263              138.210
# 2     0.13333333333333333   0.1320754716981132  0.13043478260869565
#
#   Diethyl phthalate     Cyprodinil   Tetramethrin             Captafol  \
# 0     DTXSID7021780  DTXSID1032359  DTXSID6032649        DTXSID4020242
# 1           222.240        225.295        331.412              349.050
# 2             0.125          0.125          0.125  0.12280701754385964
#
#               o-Cresol
# 0        DTXSID8021808
# 1              108.140
# 2  0.12195121951219512
# MGR - total targets: 57 - Targets positive: 8 - Total targets decimal: 11.97 - weighted and averaged limit 87080.62 [mg/kg/day]
# DEV - total targets: 38 - Targets positive: 13 - Total targets decimal: 13.21 - weighted and averaged limit 50240.22 [mg/kg/day]
# SAC - total targets: 63 - Targets positive: 9 - Total targets decimal: 7.70 - weighted and averaged limit 17437.99 [mg/kg/day]
# CHR - total targets: 77 - Targets positive: 26 - Total targets decimal: 29.48 - weighted and averaged limit 69375.50 [mg/kg/day]
# SUB - total targets: 96 - Targets positive: 31 - Total targets decimal: 35.52 - weighted and averaged limit 230734.19 [mg/kg/day]
#      preferred name       Nitrogen            Cyanamide         Acetonitrile  \
# 0        dsstox_sid  DTXSID4036304        DTXSID9034490        DTXSID7020009
# 1  molecular weight         28.014               42.041               41.053
# 2        similarity        1.00001  0.14285714285714285  0.14285714285714285
#
#   Calcium cyanamide Dibromoacetonitrile  Acrylonitrile Dichloroacetonitrile  \
# 0     DTXSID6020353       DTXSID3024940  DTXSID5020029        DTXSID3021562
# 1            80.103             198.845         53.064              109.940
# 2             0.125                 0.1            0.1                  0.1
#
#    Propionitrile
# 0  DTXSID1021879
# 1         55.080
# 2            0.1
# SUB - total targets: 89 - Targets positive: 31 - Total targets decimal: 29.46 - weighted and averaged limit 8060.36 [mg/kg/day]
# CHR - total targets: 84 - Targets positive: 35 - Total targets decimal: 37.05 - weighted and averaged limit 4267.93 [mg/kg/day]
# MGR - total targets: 40 - Targets positive: 3 - Total targets decimal: 3.00 - weighted and averaged limit 43.75 [mg/kg/day]
# DEV - total targets: 35 - Targets positive: 12 - Total targets decimal: 12.85 - weighted and averaged limit 15145.34 [mg/kg/day]
#      preferred name Carbon dioxide  Dibromoacetonitrile  \
# 0        dsstox_sid  DTXSID4027028        DTXSID3024940
# 1  molecular weight         44.009              198.845
# 2        similarity        1.00001  0.18181818181818182
#
#   1,6-Diisocyanatohexane               Silica           Cyanamide  \
# 0          DTXSID4024143        DTXSID1029677       DTXSID9034490
# 1                168.196               60.083              42.041
# 2    0.15789473684210525  0.14285714285714285  0.1111111111111111
#
#             Formamide   Sulfuryl fluoride        Arsenic acid  \
# 0       DTXSID8025337       DTXSID9034945       DTXSID1034341
# 1              45.041             102.050             141.942
# 2  0.1111111111111111  0.1111111111111111  0.1111111111111111
#
#                  Urea    Chromic(VI) acid        Acetonitrile  \
# 0       DTXSID4021426       DTXSID8034455       DTXSID7020009
# 1              60.056             118.008              41.053
# 2  0.1111111111111111  0.1111111111111111  0.1111111111111111
#
#   2,2-Dibromo-3-nitrilopropionamide Chlorothalonil Sodium nitrite  \
# 0                     DTXSID5032361  DTXSID0020319  DTXSID0020941
# 1                           241.870        265.900         68.995
# 2               0.10526315789473684            0.1            0.1
#
#   Barium metaborate Trisodium arsenate
# 0     DTXSID1034347      DTXSID9039367
# 1           222.940            207.887
# 2               0.1                0.1
# MGR - total targets: 48 - Targets positive: 9 - Total targets decimal: 12.86 - weighted and averaged limit 16475.97 [mg/kg/day]
# DEV - total targets: 49 - Targets positive: 24 - Total targets decimal: 25.48 - weighted and averaged limit 94434.88 [mg/kg/day]
# SAC - total targets: 54 - Targets positive: 10 - Total targets decimal: 17.00 - weighted and averaged limit 161375.00 [mg/kg/day]
# CHR - total targets: 92 - Targets positive: 37 - Total targets decimal: 45.10 - weighted and averaged limit 37591.27 [mg/kg/day]
# SUB - total targets: 100 - Targets positive: 39 - Total targets decimal: 43.81 - weighted and averaged limit 172850.40 [mg/kg/day]
#      preferred name   Formaldehyde           Acrylamide               Silica  \
# 0        dsstox_sid  DTXSID7020637        DTXSID5020027        DTXSID1029677
# 1  molecular weight         30.026               71.079               60.083
# 2        similarity        1.00001  0.16666666666666666  0.16666666666666666
#
#         Methacrylamide      Formamide Sulfuryl fluoride   Arsenic acid  \
# 0        DTXSID8029600  DTXSID8025337     DTXSID9034945  DTXSID1034341
# 1               85.106         45.041           102.050        141.942
# 2  0.15384615384615385          0.125             0.125          0.125
#
#             Urea Chromic(VI) acid      Sodium nitrite  \
# 0  DTXSID4021426    DTXSID8034455       DTXSID0020941
# 1         60.056          118.008              68.995
# 2          0.125            0.125  0.1111111111111111
#
#   2,2-Dibromo-3-nitrilopropionamide   Barium metaborate  Trisodium arsenate  \
# 0                     DTXSID5032361       DTXSID1034347       DTXSID9039367
# 1                           241.870             222.940             207.887
# 2                0.1111111111111111  0.1111111111111111  0.1111111111111111
#
#        Silver nitrate Dimethylarsinic acid      Acetamide
# 0       DTXSID3032042        DTXSID7020508  DTXSID7020005
# 1             169.872              137.998         59.068
# 2  0.1111111111111111                  0.1            0.1
# MGR - total targets: 47 - Targets positive: 10 - Total targets decimal: 12.54 - weighted and averaged limit 11249.90 [mg/kg/day]
# DEV - total targets: 46 - Targets positive: 19 - Total targets decimal: 21.07 - weighted and averaged limit 38230.93 [mg/kg/day]
# SAC - total targets: 53 - Targets positive: 22 - Total targets decimal: 22.00 - weighted and averaged limit 194958.00 [mg/kg/day]
# CHR - total targets: 72 - Targets positive: 17 - Total targets decimal: 22.43 - weighted and averaged limit 30239.86 [mg/kg/day]
# SUB - total targets: 100 - Targets positive: 45 - Total targets decimal: 48.13 - weighted and averaged limit 162700.78 [mg/kg/day]
# [55, 12, 8.5, 3469.125, 'MGR']
# [48, 23, 23.500999999999998, 87704.346, 'DEV']
# [74, 18, 17.102999999999998, 94654.43500000001, 'SAC']
# [78, 24, 27.83, 9685.57155, 'CHR']
# [92, 32, 33.754, 84568.60789749998, 'SUB']
# [53, 4, 4.0, 560.0, 'MGR']
# [55, 29, 31.153, 105303.36472817462, 'DEV']
# [43, 3, 3.0, 61250.0, 'SAC']
# [34, 10, 10.0, 47812.5, 'REP']
# [60, 5, 8.599, 47705.14879999999, 'CHR']
# [86, 18, 23.104999999999997, 180007.59185603168, 'SUB']
# [92, 31, 33.057, 217667.04906593403, 'SUB']
# [34, 10, 10.0, 20269.230769230762, 'REP']
# [56, 6, 7.75, 12210.221472509158, 'CHR']
# [58, 34, 34.753, 83943.21579487182, 'DEV']
# [59, 17, 16.881999999999998, 42238.867125000004, 'MGR']
# [42, 18, 19.232, 37290.5565, 'DEV']
# [51, 6, 8.109, 859.2290333333334, 'SAC']
# [33, 4, 4.962, 284.18, 'REP']
# [77, 22, 26.598000000000003, 92372.02307333333, 'CHR']
# [93, 33, 37.00900000000002, 165337.13294555334, 'SUB']
# [57, 8, 11.967999999999998, 87080.62390214285, 'MGR']
# [38, 13, 13.206000000000001, 50240.221428571436, 'DEV']
# [63, 9, 7.704999999999999, 17437.992080000004, 'SAC']
# [77, 26, 29.480999999999998, 69375.49785990478, 'CHR']
# [96, 31, 35.52399999999999, 230734.1889214286, 'SUB']
# [89, 31, 29.458, 8060.357599999997, 'SUB']
# [84, 35, 37.053, 4267.9325, 'CHR']
# [40, 3, 3.0, 43.75, 'MGR']
# [35, 12, 12.850999999999999, 15145.335000000001, 'DEV']
# [48, 9, 12.855, 16475.9675, 'MGR']
# [49, 24, 25.482999999999993, 94434.88000000002, 'DEV']
# [54, 10, 17.0, 161375.0, 'SAC']
# [92, 37, 45.103000000000016, 37591.27448466667, 'CHR']
# [100, 39, 43.81299999999998, 172850.40226749994, 'SUB']
# [47, 10, 12.541999999999998, 11249.897999999997, 'MGR']
# [46, 19, 21.070000000000007, 38230.93000000001, 'DEV']
# [53, 22, 22.0, 194958.0, 'SAC']
# [72, 17, 22.433999999999997, 30239.856280000004, 'CHR']
# [100, 45, 48.129999999999995, 162700.78285499994, 'SUB']
# [4, 4, 3.848, 10472.426, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [1, 1, 1.0, 68.75, ':bile duct', 'CHR']
# [1, 1, 1.0, 698.25, ':thyroxine (t4)', 'CHR']
# [4, 1, 1.231, 4685.1553, ':testes', 'SUB']
# [4, 1, 1.392, 12221.58475, ':lung', 'SUB']
# [1, 0, 0.0, 0.0, ':preputial separation', 'MGR']
# [4, 0, 0.0, 0.0, ':seminal vesicle', 'SUB']
# [3, 3, 2.468, 8901.3995, ':hematocrit (hct)', 'SUB']
# [3, 0, 0.308, 85.932, ':thyroid gland', 'SUB']
# [1, 0, 0.0, 0.0, ':trunk', 'DEV']
# [3, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [2, 0, 0.0, 0.0, ':offspring survival early other', 'MGR']
# [3, 0, 0.0, 0.0, ':ear', 'SUB']
# [2, 2, 1.734, 884.76, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [2, 0, 0.0, 0.0, ':dead fetuses', 'MGR']
# [3, 0, 0.154, 31.416, ':parathyroid gland', 'SUB']
# [2, 0, 0.0, 0.0, ':dystocia', 'MGR']
# [2, 2, 2.0, 1308.0, ':nucleated red blood cell (nrbc)', 'SUB']
# [2, 2, 2.0, 4845.77, ':neutrophils', 'SUB']
# [1, 1, 1.0, 165.0, ':methemoglobin', 'SUB']
# [5, 4, 4.083, 20314.42206, ':body weight', 'SUB']
# [3, 0, 0.246, 408.48300000000006, ':bone marrow', 'SUB']
# [2, 0, 0.11, 391.875, ':resorptions', 'MGR']
# [1, 1, 1.0, 1375.0, ':blood', 'SUB']
# [2, 2, 1.734, 972.76, ':reticulocyte', 'SUB']
# [5, 2, 2.252, 10422.0770625, ':kidney', 'SUB']
# [3, 0, 0.0, 0.0, ':gallbladder', 'SUB']
# [1, 1, 0.5, 64.5, ':lactation index', 'MGR']
# [2, 0, 0.0, 0.0, ':implantations', 'MGR']
# [1, 0, 0.0, 0.0, ':precoital interval', 'MGR']
# [3, 1, 0.9530000000000001, 1113.34225, ':volume', 'SUB']
# [1, 1, 1.0, 3.4375, ':non-protein sulfhydryl (npsh)', 'SUB']
# [1, 1, 1.0, 698.25, ':triiodothyronine (t3)', 'CHR']
# [2, 2, 1.242, 3111.5205, ':urea nitrogen', 'SUB']
# [3, 0, 0.251, 148.3922, ':pancreas', 'SUB']
# [1, 0, 0.0, 0.0, ':viability index', 'MGR']
# [2, 2, 2.0, 2073.25, ':calcium', 'SUB']
# [1, 1, 1.0, 698.25, ':peritoneum', 'CHR']
# [1, 1, 1.0, 1375.0, ':lipids', 'SUB']
# [1, 1, 1.0, 1375.0, ':glutamate dehydrogenase', 'SUB']
# [3, 1, 0.621, 3009.0555, ':leukocyte (wbc) count differential', 'SUB']
# [1, 1, 1.0, 540.0, ':paw / digit', 'DEV']
# [4, 0, 0.626, 1174.9696, ':spleen', 'SUB']
# [2, 0, 0.278, 27.522000000000002, ':aborted', 'MGR']
# [2, 0, 0.0, 0.0, ':litter size', 'MGR']
# [3, 0, 0.0, 0.0, ':pharynx', 'SUB']
# [1, 1, 1.0, 3888.5, ':albumin-globulin ratio', 'SUB']
# [1, 0, 0.0, 0.0, ':lacrimal gland', 'SUB']
# [4, 1, 0.5, 230.25, ':prostate', 'SUB']
# [5, 3, 3.029, 8547.956, ':food consumption', 'SUB']
# [1, 1, 0.5, 84.375, ':fertility', 'MGR']
# [5, 0, 0.383, 1157.085, ':uterus', 'SUB']
# [4, 0, 0.116, 93.96000000000001, ':full gross necropsy', 'SUB']
# [1, 0, 0.299, 11.959999999999999, ':bile acids', 'SUB']
# [2, 0, 0.0, 0.0, ':pregnancy', 'MGR']
# [2, 1, 1.177, 1385.62, ':specific gravity/osmolality', 'SUB']
# [1, 1, 0.5, 797.3, ':alkaline phosphatase (alp/alk)', 'SUB']
# [2, 0, 0.0, 0.0, ':reproductive performance other', 'MGR']
# [5, 2, 1.7610000000000001, 9056.896625000001, ':mortality', 'SUB']
# [1, 1, 1.0, 56.0, ':oral mucosa', 'CHR']
# [2, 1, 1.0, 450.0, ':general', 'SAC']
# [3, 3, 2.5, 1893.25, ':[other]', 'MGR']
# [2, 0, 0.0, 0.0, ':postimplantation loss', 'MGR']
# [3, 0, 0.0, 0.0, ':esophagus', 'SUB']
# [3, 0, 0.0, 0.0, ':preputial gland', 'SUB']
# [2, 1, 0.831, 1739.6465625, ':creatinine', 'SUB']
# [1, 0, 0.0, 0.0, ':vaginal opening', 'MGR']
# [3, 0, 0.261, 200.71699999999998, ':intestine large', 'SUB']
# [5, 4, 3.715, 12252.913249999998, ':liver', 'SUB']
# [4, 4, 3.023, 9374.1234, ':erythrocyte (rbc) count differential', 'SUB']
# [3, 3, 2.246, 5811.368, ':cholesterol', 'SUB']
# [2, 1, 1.0, 1375.0, ':blood clotting', 'SUB']
# [3, 2, 2.0, 2462.5, ':estrous cycle', 'SUB']
# [2, 0, 0.0, 0.0, ':birth index', 'MGR']
# [4, 1, 1.0, 7665.0, ':eye', 'SUB']
# [4, 1, 1.9389999999999998, 9927.590000000002, ':stomach', 'SUB']
# [4, 0, 0.0, 0.0, ':pituitary gland', 'SUB']
# [2, 2, 1.512, 4915.1496, ':triglycerides', 'SUB']
# [1, 0, 0.0, 0.0, ':oviduct', 'MGR']
# [3, 1, 1.0, 735.75, ':albumin', 'SUB']
# [5, 1, 1.131, 594.5076, ':thymus', 'SUB']
# [3, 0, 0.177, 123.59025, ':ph', 'SUB']
# [3, 1, 0.7110000000000001, 2266.474, ':skin', 'SUB']
# [3, 0, 0.277, 0.9521875000000001, ':glucose', 'SUB']
# [1, 1, 1.0, 1760.0, ':anisocytosis', 'DEV']
# [1, 0, 0.299, 11.959999999999999, ':sorbitol dehydrogenase', 'SUB']
# [1, 1, 1.0, 1760.0, ':hypochromia', 'DEV']
# [1, 0, 0.299, 40.664, ':creatine phosphokinase', 'SUB']
# [1, 0, 0.0, 0.0, ':gestational length', 'MGR']
# [2, 0, 0.0, 0.0, ':live fetuses', 'MGR']
# [3, 0, 0.0, 0.0, ':tongue', 'SUB']
# [3, 0, 0.154, 11.55, ':mammary gland', 'SUB']
# [2, 1, 0.5, 64.5, ':litter viability other', 'MGR']
# [2, 1, 1.0, 1375.0, ':potassium', 'SUB']
# [3, 0, 0.0, 0.0, ':urinary bladder', 'SUB']
# [4, 0, 0.371, 400.68, ':bone', 'SUB']
# [2, 0, 0.0, 0.0, ':gestation index', 'MGR']
# [2, 0, 0.0, 0.0, ':corpora lutea', 'MGR']
# [1, 1, 1.0, 4845.5, ':lymphocyte', 'SAC']
# [2, 0, 0.0, 0.0, ':premature delivery', 'MGR']
# [1, 0, 0.0, 0.0, ':pregnancy index', 'MGR']
# [3, 0, 0.33499999999999996, 876.9345999999999, ':heart', 'SUB']
# [3, 3, 3.0, 8276.5, ':globulins', 'SUB']
# [5, 1, 1.704, 2927.7975, ':brain', 'SUB']
# [3, 0, 0.0, 0.0, ':nerve', 'SUB']
# [2, 0, 0.0, 0.0, ':preimplantation loss', 'MGR']
# [4, 4, 3.479, 10261.4875, ':hemoglobin (hgb)', 'SUB']
# [2, 1, 1.0, 632.5, ':sperm measure', 'SUB']
# [4, 1, 1.0, 4500.0, ':trachea', 'SUB']
# [5, 2, 2.885, 29631.8655, ':clinical signs', 'SUB']
# [1, 0, 0.0, 0.0, ':sodium', 'SAC']
# [4, 0, 0.282, 82.27349999999998, ':adrenal gland', 'SUB']
# [3, 0, 0.144, 8.064, ':salivary glands', 'SUB']
# [1, 1, 1.0, 6319.5, ':phosphorus', 'SAC']
# [2, 1, 1.446, 133.3816, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [3, 0, 0.0, 0.0, ':harderian gland', 'SUB']
# [4, 0, 0.443, 3130.9025, ':ovary', 'SUB']
# [1, 0, 0.0, 0.0, ':nipple development', 'MGR']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [2, 0, 0.0, 0.0, ':appearance and color', 'SUB']
# [4, 0, 0.0, 0.0, ':vagina', 'SUB']
# [1, 0, 0.0, 0.0, ':cervix', 'MGR']
# [4, 0, 0.0, 0.0, ':spinal cord', 'SUB']
# [3, 0, 0.0, 0.0, ':skeletal muscle', 'SUB']
# [3, 0, 0.219, 8.323800000000002, ':nose', 'SUB']
# [4, 1, 1.325, 533.1741999999999, ':intestine small', 'SUB']
# [3, 1, 1.251, 4705.24075, ':protein', 'SUB']
# [3, 0, 0.67, 368.0072, ':lymph node', 'SUB']
# [1, 0, 0.0, 0.0, ':coagulating gland', 'MGR']
# [2, 0, 0.0, 0.0, ':all gross anomalies', 'MGR']
# [1, 1, 0.5, 64.5, ':mating', 'MGR']
# [3, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [5, 5, 4.848, 10541.451000000001, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [2, 1, 0.734, 937.685, ':platelet', 'SUB']
# [4, 0, 0.181, 704.1080999999999, ':epididymis', 'SUB']
# [3, 0, 0.0, 0.0, ':larynx', 'SUB']
# [1, 0, 0.0, 0.0, ':parathyroid', 'SUB']
# [2, 0, 0.0, 0.0, ':sex ratio', 'MGR']
# [3, 3, 3.0, 2644.55, ':water consumption', 'SUB']
# [1, 1, 1.0, 1760.0, ':lipids, total', 'DEV']
# [1, 0, 0.222, 456.987, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [5, 0, 0.45399999999999996, 6005.602208333334, ':testes', 'SUB']
# [4, 1, 1.3579999999999999, 1387.5701428571429, ':lung', 'SUB']
# [1, 0, 0.0, 0.0, ':preputial separation', 'MGR']
# [4, 0, 0.095, 13.3, ':seminal vesicle', 'SUB']
# [2, 2, 1.595, 4378.692142857142, ':hematocrit (hct)', 'SUB']
# [3, 0, 0.0, 0.0, ':thyroid gland', 'SUB']
# [1, 0, 0.094, 235.67142857142855, ':trunk', 'DEV']
# [3, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [3, 0, 0.0, 0.0, ':offspring survival early other', 'REP']
# [3, 1, 1.0, 1928.5714285714284, ':ear', 'SUB']
# [3, 1, 1.085, 5637.142857142857, ':dead fetuses', 'REP']
# [1, 0, 0.0, 0.0, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [3, 0, 0.0, 0.0, ':parathyroid gland', 'SUB']
# [3, 1, 1.0, 2812.5, ':dystocia', 'REP']
# [1, 1, 1.0, 2648.5714285714284, ':limb', 'DEV']
# [6, 6, 5.528, 47597.57411190476, ':body weight', 'SUB']
# [2, 0, 0.42799999999999994, 1923.9299999999998, ':bone marrow', 'SUB']
# [3, 0, 0.221, 1482.1031746031745, ':resorptions', 'REP']
# [1, 1, 1.0, 642.8571428571429, ':mouth / jaw', 'DEV']
# [1, 0, 0.222, 665.9999999999999, ':reticulocyte', 'SUB']
# [5, 2, 2.15, 17762.175880952378, ':kidney', 'SUB']
# [4, 1, 1.0, 2648.5714285714284, ':gallbladder', 'SUB']
# [1, 0, 0.0, 0.0, ':lactation index', 'MGR']
# [3, 0, 0.201, 1615.1785714285716, ':implantations', 'REP']
# [2, 0, 0.0, 0.0, ':precoital interval', 'REP']
# [2, 0, 0.338, 6.419102857142858, ':volume', 'SUB']
# [1, 1, 1.0, 5625.0, ':eye opening', 'REP']
# [1, 0, 0.0, 0.0, ':urea nitrogen', 'SUB']
# [3, 0, 0.0, 0.0, ':pancreas', 'SUB']
# [1, 0, 0.0, 0.0, ':viability index', 'MGR']
# [3, 2, 1.62, 17798.001571428573, ':leukocyte (wbc) count differential', 'SUB']
# [1, 1, 1.0, 3542.8571428571427, ':uric acid', 'SUB']
# [1, 1, 1.0, 8183.333333333333, ':paw / digit', 'DEV']
# [5, 1, 1.51, 7387.030785714285, ':spleen', 'SUB']
# [3, 0, 0.0, 0.0, ':aborted', 'REP']
# [3, 0, 0.0, 0.0, ':litter size', 'REP']
# [2, 0, 0.0, 0.0, ':pharynx', 'SUB']
# [4, 0, 0.188, 414.4057142857143, ':prostate', 'SUB']
# [6, 2, 2.8299999999999996, 29971.975470238096, ':food consumption', 'SUB']
# [2, 1, 1.0, 5625.0, ':fertility', 'REP']
# [1, 1, 1.0, 140.0, ':cholinesterase', 'SUB']
# [6, 0, 0.754, 5767.500714285716, ':uterus', 'SUB']
# [3, 0, 0.385, 2072.8924285714284, ':full gross necropsy', 'SUB']
# [1, 0, 0.0, 0.0, ':bile acids', 'SUB']
# [3, 0, 0.127, 182.03333333333333, ':pregnancy', 'REP']
# [2, 1, 1.0, 2161.848571428571, ':specific gravity/osmolality', 'SUB']
# [1, 0, 0.366, 804.651, ':alkaline phosphatase (alp/alk)', 'SUB']
# [2, 0, 0.0, 0.0, ':reproductive performance other', 'MGR']
# [6, 2, 3.0749999999999997, 62243.72949801588, ':mortality', 'SUB']
# [2, 2, 2.0, 6770.392857142857, ':general', 'REP']
# [1, 1, 1.0, 1785.7142857142856, ':ureter', 'DEV']
# [3, 2, 2.0, 285.1428571428571, ':[other]', 'SUB']
# [3, 0, 0.345, 2039.5523809523806, ':postimplantation loss', 'REP']
# [3, 0, 0.0, 0.0, ':esophagus', 'SUB']
# [1, 1, 1.0, 1983.5714285714282, ':aspartate aminotransferase (ast/sgot)', 'SUB']
# [4, 0, 0.0, 0.0, ':preputial gland', 'SUB']
# [1, 0, 0.0, 0.0, ':creatinine', 'SUB']
# [1, 0, 0.0, 0.0, ':vaginal opening', 'MGR']
# [3, 0, 0.0, 0.0, ':intestine large', 'SUB']
# [5, 4, 3.258, 25559.49016031746, ':liver', 'SUB']
# [3, 2, 1.683, 7107.6668, ':erythrocyte (rbc) count differential', 'SUB']
# [1, 0, 0.299, 1264.2716666666665, ':cholesterol', 'SUB']
# [2, 0, 0.0, 0.0, ':birth index', 'MGR']
# [2, 1, 1.0, 1928.5714285714284, ':estrous cycle', 'MGR']
# [4, 1, 1.28, 1126.5, ':eye', 'SUB']
# [4, 1, 1.7790000000000001, 22379.117827380953, ':stomach', 'SUB']
# [4, 0, 0.0, 0.0, ':pituitary gland', 'SUB']
# [1, 0, 0.299, 1482.8406666666665, ':triglycerides', 'SUB']
# [1, 0, 0.0, 0.0, ':oviduct', 'MGR']
# [2, 1, 1.2429999999999999, 2017.2857142857142, ':albumin', 'SUB']
# [1, 1, 1.0, 642.8571428571429, ':great vessels', 'DEV']
# [4, 0, 0.326, 3963.95625, ':thymus', 'SUB']
# [2, 0, 0.0, 0.0, ':ph', 'SUB']
# [3, 0, 0.0, 0.0, ':skin', 'SUB']
# [2, 0, 0.312, 50.36571428571428, ':glucose', 'SUB']
# [1, 0, 0.0, 0.0, ':sorbitol dehydrogenase', 'SUB']
# [1, 0, 0.0, 0.0, ':creatine phosphokinase', 'SUB']
# [2, 0, 0.0, 0.0, ':gestational length', 'REP']
# [2, 0, 0.323, 1424.0999503968255, ':live fetuses', 'MGR']
# [3, 0, 0.0, 0.0, ':tongue', 'SUB']
# [3, 0, 0.0, 0.0, ':mammary gland', 'SUB']
# [3, 1, 1.085, 3358.9285714285716, ':litter viability other', 'REP']
# [1, 1, 1.0, 479.57142857142856, ':potassium', 'SUB']
# [3, 0, 0.232, 394.30091428571427, ':urinary bladder', 'SUB']
# [4, 1, 1.046, 20782.59966666667, ':bone', 'SUB']
# [3, 0, 0.0, 0.0, ':gestation index', 'REP']
# [3, 0, 0.0, 0.0, ':corpora lutea', 'REP']
# [1, 1, 1.0, 22736.25, ':lymphocyte', 'SUB']
# [3, 1, 1.0, 734.375, ':pregnancy index', 'REP']
# [3, 0, 0.0, 0.0, ':premature delivery', 'REP']
# [4, 1, 1.2209999999999999, 856.6642857142856, ':heart', 'SUB']
# [1, 1, 1.0, 6333.333333333334, ':globulins', 'SUB']
# [5, 1, 1.095, 3375.2047619047617, ':brain', 'SUB']
# [3, 0, 0.095, 0.665, ':nerve', 'SUB']
# [3, 0, 0.0, 0.0, ':preimplantation loss', 'REP']
# [2, 2, 1.63, 6216.215142857143, ':hemoglobin (hgb)', 'SUB']
# [1, 1, 1.0, 140.0, ':sperm measure', 'MGR']
# [3, 0, 0.0, 0.0, ':trachea', 'SUB']
# [6, 1, 1.198, 10167.679281746032, ':clinical signs', 'SUB']
# [4, 0, 0.43099999999999994, 1283.5266714285713, ':adrenal gland', 'SUB']
# [3, 0, 0.0, 0.0, ':salivary glands', 'SUB']
# [1, 1, 1.0, 5625.0, ':pinna unfolding', 'REP']
# [3, 0, 0.362, 1018.125, ':harderian gland', 'SUB']
# [5, 0, 0.113, 2569.19625, ':ovary', 'SUB']
# [1, 0, 0.299, 3897.099555555555, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [1, 0, 0.0, 0.0, ':nipple development', 'MGR']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [2, 0, 0.0, 0.0, ':appearance and color', 'SUB']
# [5, 1, 1.0, 357.1428571428571, ':vagina', 'SUB']
# [1, 0, 0.0, 0.0, ':cervix', 'MGR']
# [3, 0, 0.141, 19.74, ':spinal cord', 'SUB']
# [3, 0, 0.225, 31.5, ':skeletal muscle', 'SUB']
# [3, 0, 0.278, 1113.75, ':nose', 'SUB']
# [3, 0, 0.0, 0.0, ':intestine small', 'SUB']
# [2, 0, 0.642, 2243.583971428572, ':protein', 'SUB']
# [2, 1, 0.676, 4287.031328571428, ':lymph node', 'SUB']
# [1, 0, 0.0, 0.0, ':coagulating gland', 'MGR']
# [3, 0, 0.0, 0.0, ':all gross anomalies', 'REP']
# [2, 0, 0.0, 0.0, ':mating', 'REP']
# [2, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [2, 1, 1.0, 642.8571428571429, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [1, 1, 1.0, 4972.541904761904, ':bilirubin', 'SUB']
# [2, 1, 1.0, 642.8571428571429, ':platelet', 'SUB']
# [5, 0, 0.095, 13.3, ':epididymis', 'SUB']
# [3, 0, 0.0, 0.0, ':larynx', 'SUB']
# [1, 1, 1.0, 305.5, ':ketones', 'SUB']
# [1, 0, 0.0, 0.0, ':parathyroid', 'SUB']
# [3, 0, 0.0, 0.0, ':sex ratio', 'REP']
# [1, 1, 1.0, 1433.3333333333333, ':placenta', 'DEV']
# [2, 2, 2.0, 3025.658095238095, ':water consumption', 'SUB']
# [1, 0, 0.236, 105.02, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [3, 0, 0.505, 4330.66857142857, ':testes', 'SUB']
# [3, 1, 1.2249999999999999, 1376.5351085714283, ':lung', 'SUB']
# [1, 1, 1.0, 2672.5, ':polychromasia', 'SUB']
# [2, 0, 0.0, 0.0, ':seminal vesicle', 'SUB']
# [2, 2, 1.537, 2004.0393758241755, ':hematocrit (hct)', 'SUB']
# [2, 0, 0.0, 0.0, ':thyroid gland', 'SUB']
# [1, 0, 0.101, 202.5771428571429, ':trunk', 'DEV']
# [2, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [2, 0, 0.0, 0.0, ':offspring survival early other', 'REP']
# [3, 1, 1.0, 1542.857142857143, ':ear', 'SUB']
# [2, 1, 1.0, 2384.6153846153843, ':dead fetuses', 'REP']
# [1, 0, 0.12, 28.152, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [2, 0, 0.0, 0.0, ':parathyroid gland', 'SUB']
# [2, 1, 1.0, 1192.3076923076922, ':dystocia', 'REP']
# [1, 1, 1.0, 2118.8571428571427, ':limb', 'DEV']
# [1, 1, 1.0, 155.0, ':methemoglobin', 'SUB']
# [2, 1, 1.072, 3906.978269230769, ':bone marrow', 'SUB']
# [4, 4, 3.855, 36735.419985576926, ':body weight', 'SUB']
# [2, 0, 0.271, 2170.580952380952, ':resorptions', 'REP']
# [1, 1, 1.0, 514.2857142857142, ':mouth / jaw', 'DEV']
# [1, 0, 0.132, 81.84, ':reticulocyte', 'SUB']
# [3, 3, 2.255, 16156.35221978022, ':kidney', 'SUB']
# [3, 1, 1.0, 2118.8571428571427, ':gallbladder', 'SUB']
# [2, 0, 0.318, 1237.054945054945, ':implantations', 'REP']
# [1, 0, 0.0, 0.0, ':precoital interval', 'REP']
# [2, 0, 0.0, 0.0, ':volume', 'SUB']
# [1, 1, 1.0, 2384.6153846153843, ':eye opening', 'REP']
# [1, 0, 0.12, 28.152, ':urea nitrogen', 'SUB']
# [2, 0, 0.087, 630.75, ':pancreas', 'SUB']
# [1, 1, 1.0, 234.60000000000002, ':calcium', 'SUB']
# [2, 2, 1.601, 8270.149214285713, ':leukocyte (wbc) count differential', 'SUB']
# [1, 1, 1.0, 4711.538461538461, ':paw / digit', 'DEV']
# [3, 1, 1.821, 3997.164366575091, ':spleen', 'SUB']
# [2, 0, 0.0, 0.0, ':aborted', 'REP']
# [2, 0, 0.0, 0.0, ':litter size', 'REP']
# [2, 0, 0.0, 0.0, ':pharynx', 'SUB']
# [1, 1, 1.0, 234.60000000000002, ':albumin-globulin ratio', 'SUB']
# [2, 0, 0.0, 0.0, ':prostate', 'SUB']
# [4, 2, 1.4569999999999999, 33140.83257142857, ':food consumption', 'SUB']
# [1, 1, 1.0, 2384.6153846153843, ':fertility', 'REP']
# [4, 0, 0.9179999999999999, 3835.1791679670328, ':uterus', 'SUB']
# [3, 0, 0.379, 242.91392857142856, ':full gross necropsy', 'SUB']
# [1, 0, 0.132, 163.68, ':bile acids', 'SUB']
# [2, 0, 0.084, 155.4, ':pregnancy', 'REP']
# [1, 0, 0.0, 0.0, ':specific gravity/osmolality', 'CHR']
# [1, 0, 0.132, 20.46, ':alkaline phosphatase (alp/alk)', 'SUB']
# [1, 0, 0.0, 0.0, ':reproductive performance other', 'DEV']
# [4, 3, 2.71, 25452.424938663004, ':mortality', 'SUB']
# [2, 2, 2.0, 3755.0505494505496, ':general', 'REP']
# [1, 1, 1.0, 2537.5, ':[other]', 'SUB']
# [2, 0, 0.367, 2376.027904761904, ':postimplantation loss', 'REP']
# [2, 0, 0.0, 0.0, ':esophagus', 'SUB']
# [3, 0, 0.0, 0.0, ':preputial gland', 'SUB']
# [1, 0, 0.12, 28.152, ':creatinine', 'SUB']
# [2, 0, 0.0, 0.0, ':intestine large', 'SUB']
# [3, 3, 2.309, 21004.20414675824, ':liver', 'SUB']
# [2, 2, 1.603, 3898.6927912087913, ':erythrocyte (rbc) count differential', 'SUB']
# [1, 0, 0.117, 638.5275, ':cholesterol', 'SUB']
# [1, 0, 0.0, 0.0, ':birth index', 'DEV']
# [2, 2, 2.0, 2490.357142857143, ':estrous cycle', 'SUB']
# [3, 1, 1.146, 222.17142857142858, ':eye', 'SUB']
# [4, 4, 3.154, 22944.912619999996, ':stomach', 'SUB']
# [2, 0, 0.0, 0.0, ':pituitary gland', 'SUB']
# [1, 0, 0.117, 748.917, ':triglycerides', 'SUB']
# [1, 0, 0.257, 1321.8366666666666, ':albumin', 'SUB']
# [1, 1, 1.0, 514.2857142857142, ':great vessels', 'DEV']
# [2, 1, 0.608, 10213.993553113552, ':thymus', 'SUB']
# [2, 0, 0.0, 0.0, ':ph', 'SUB']
# [2, 0, 0.138, 0.21677500000000002, ':skin', 'SUB']
# [2, 0, 0.12, 16.2, ':glucose', 'SUB']
# [1, 1, 1.0, 135.0, ':anisocytosis', 'SUB']
# [1, 0, 0.0, 0.0, ':sorbitol dehydrogenase', 'SUB']
# [1, 1, 1.0, 135.0, ':hypochromia', 'SUB']
# [1, 0, 0.0, 0.0, ':creatine phosphokinase', 'SUB']
# [1, 0, 0.0, 0.0, ':gestational length', 'REP']
# [1, 0, 0.497, 2334.7166666666662, ':live fetuses', 'DEV']
# [2, 0, 0.0, 0.0, ':tongue', 'SUB']
# [2, 0, 0.138, 0.21677500000000002, ':mammary gland', 'SUB']
# [2, 1, 1.0, 1192.3076923076922, ':litter viability other', 'REP']
# [1, 1, 1.0, 135.0, ':potassium', 'SUB']
# [3, 1, 1.068, 659.6666666666666, ':urinary bladder', 'SUB']
# [3, 1, 1.42, 10014.877604395602, ':bone', 'SUB']
# [2, 0, 0.0, 0.0, ':gestation index', 'REP']
# [2, 0, 0.0, 0.0, ':corpora lutea', 'REP']
# [1, 1, 1.0, 8898.880952380952, ':lymphocyte', 'SUB']
# [2, 1, 1.0, 285.7142857142857, ':pregnancy index', 'REP']
# [2, 0, 0.0, 0.0, ':premature delivery', 'REP']
# [3, 1, 1.293, 741.5607035714286, ':heart', 'SUB']
# [1, 1, 1.0, 5067.933333333333, ':globulins', 'SUB']
# [3, 1, 1.0, 3392.857142857143, ':brain', 'SUB']
# [2, 0, 0.0, 0.0, ':nerve', 'SUB']
# [2, 0, 0.0, 0.0, ':preimplantation loss', 'REP']
# [2, 2, 1.603, 3898.6927912087913, ':hemoglobin (hgb)', 'SUB']
# [1, 1, 1.0, 79.75, ':sperm measure', 'SUB']
# [3, 1, 1.0, 450.0, ':trachea', 'SUB']
# [4, 2, 1.538, 18655.754377289377, ':clinical signs', 'SUB']
# [3, 1, 1.48, 2396.2373333333335, ':adrenal gland', 'SUB']
# [2, 0, 0.0, 0.0, ':salivary glands', 'SUB']
# [1, 1, 1.0, 2384.6153846153843, ':pinna unfolding', 'REP']
# [1, 1, 1.0, 135.0, ':phosphorus', 'SUB']
# [2, 0, 0.503, 407.7964666025641, ':harderian gland', 'SUB']
# [3, 0, 0.41000000000000003, 3057.011060714286, ':ovary', 'SUB']
# [1, 0, 0.233, 3955.7963333333328, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [1, 0, 0.0, 0.0, ':appearance and color', 'CHR']
# [3, 1, 1.0, 300.0, ':vagina', 'SUB']
# [3, 0, 0.0, 0.0, ':spinal cord', 'SUB']
# [2, 0, 0.0, 0.0, ':skeletal muscle', 'SUB']
# [2, 0, 0.525, 956.051923076923, ':nose', 'SUB']
# [2, 0, 0.09, 672.0, ':intestine small', 'SUB']
# [2, 0, 0.335, 1801.6076666666668, ':protein', 'SUB']
# [2, 1, 1.067, 3601.7938461538456, ':lymph node', 'SUB']
# [1, 1, 1.0, 2537.5, ':jolly bodies', 'SUB']
# [1, 1, 1.0, 135.0, ':macrocytosis', 'SUB']
# [2, 0, 0.0, 0.0, ':all gross anomalies', 'REP']
# [1, 0, 0.0, 0.0, ':mating', 'REP']
# [2, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [1, 1, 1.0, 135.0, ':chloride', 'SUB']
# [2, 1, 1.236, 619.3057142857142, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [1, 1, 1.0, 6401.0, ':bilirubin', 'SUB']
# [2, 1, 1.0, 514.2857142857142, ':platelet', 'SUB']
# [3, 0, 0.0, 0.0, ':epididymis', 'SUB']
# [2, 0, 0.0, 0.0, ':larynx', 'SUB']
# [1, 1, 1.0, 281.66666666666663, ':ketones', 'SUB']
# [2, 0, 0.0, 0.0, ':sex ratio', 'REP']
# [1, 1, 1.0, 1850.0, ':placenta', 'DEV']
# [2, 2, 2.0, 6237.5, ':water consumption', 'SUB']
# [1, 1, 0.523, 197.4325, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [1, 1, 1.0, 698.25, ':thyroxine (t4)', 'CHR']
# [5, 2, 1.96, 18686.639799999997, ':testes', 'SUB']
# [1, 1, 1.0, 1359.2, ':gamma glutamyl transpeptides (gtp)', 'SUB']
# [4, 2, 2.178, 4139.835321979999, ':lung', 'SUB']
# [1, 0, 0.0, 0.0, ':preputial separation', 'MGR']
# [4, 0, 0.0, 0.0, ':seminal vesicle', 'SUB']
# [2, 2, 1.576, 778.6032, ':hematocrit (hct)', 'SUB']
# [4, 1, 1.3970000000000002, 1859.13562, ':thyroid gland', 'SUB']
# [1, 0, 0.222, 274.725, ':trunk', 'DEV']
# [3, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [3, 0, 0.0, 0.0, ':offspring survival early other', 'REP']
# [3, 0, 0.0, 0.0, ':ear', 'SUB']
# [2, 1, 1.44, 1325.6480000000001, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [3, 1, 1.0, 130.0, ':dead fetuses', 'REP']
# [3, 0, 0.055, 11.22, ':parathyroid gland', 'SUB']
# [3, 0, 0.0, 0.0, ':dystocia', 'REP']
# [1, 1, 1.0, 1237.5, ':limb', 'DEV']
# [2, 2, 2.0, 325.0, ':nucleated red blood cell (nrbc)', 'SUB']
# [1, 1, 1.0, 398.95833333333337, ':neutrophils', 'SUB']
# [6, 5, 4.373, 43143.329983333344, ':body weight', 'SUB']
# [3, 1, 0.6, 2404.7994999999996, ':bone marrow', 'SUB']
# [3, 0, 0.44, 612.1133333333333, ':resorptions', 'REP']
# [1, 1, 0.576, 425.77919999999995, ':reticulocyte', 'SUB']
# [4, 2, 1.7960000000000003, 19977.337923333333, ':kidney', 'SUB']
# [4, 1, 1.0, 1100.0, ':gallbladder', 'SUB']
# [1, 0, 0.114, 14.706000000000001, ':lactation index', 'MGR']
# [3, 0, 0.0, 0.0, ':implantations', 'REP']
# [2, 0, 0.0, 0.0, ':precoital interval', 'REP']
# [2, 1, 1.329, 1146.55595, ':volume', 'SUB']
# [1, 1, 1.0, 698.25, ':triiodothyronine (t3)', 'CHR']
# [1, 0, 0.487, 1085.5717, ':urea nitrogen', 'SUB']
# [3, 0, 0.37, 583.6466666666668, ':pancreas', 'SUB']
# [1, 0, 0.0, 0.0, ':viability index', 'MGR']
# [1, 1, 1.0, 698.25, ':calcium', 'CHR']
# [1, 1, 1.0, 698.25, ':peritoneum', 'CHR']
# [1, 1, 1.0, 137.5, ':lipids', 'SUB']
# [1, 1, 1.0, 30.0, ':glutamate dehydrogenase', 'CHR']
# [2, 1, 0.74, 20345.066666666666, ':leukocyte (wbc) count differential', 'SUB']
# [5, 1, 1.8329999999999997, 3271.9618333333333, ':spleen', 'SUB']
# [3, 0, 0.284, 144.83999999999997, ':aborted', 'REP']
# [3, 1, 1.019, 3071.0913499999997, ':litter size', 'REP']
# [3, 0, 0.0, 0.0, ':pharynx', 'SUB']
# [1, 0, 0.0, 0.0, ':lacrimal gland', 'SUB']
# [4, 1, 0.594, 832.7434499999999, ':prostate', 'SUB']
# [6, 3, 3.2899999999999996, 25464.263166666668, ':food consumption', 'SUB']
# [2, 1, 0.83, 3183.548, ':fertility', 'REP']
# [6, 0, 0.513, 391.2282000000001, ':uterus', 'SUB']
# [5, 1, 1.1280000000000001, 313.956, ':full gross necropsy', 'SUB']
# [1, 0, 0.273, 897.897, ':bile acids', 'SUB']
# [3, 0, 0.284, 161.88, ':pregnancy', 'REP']
# [2, 1, 1.198, 1038.2064, ':specific gravity/osmolality', 'SUB']
# [1, 0, 0.423, 2783.5515, ':alkaline phosphatase (alp/alk)', 'SUB']
# [2, 0, 0.284, 166.14, ':reproductive performance other', 'MGR']
# [6, 3, 2.3529999999999998, 16980.023453533337, ':mortality', 'SUB']
# [1, 1, 1.0, 0.5, ':dopamine', 'SAC']
# [1, 1, 1.0, 2422.5, ':general', 'DEV']
# [3, 2, 2.114, 1785.706, ':[other]', 'SUB']
# [3, 0, 0.218, 76.66333333333333, ':postimplantation loss', 'REP']
# [3, 0, 0.0, 0.0, ':esophagus', 'SUB']
# [2, 2, 2.0, 2489.2, ':aspartate aminotransferase (ast/sgot)', 'SUB']
# [1, 1, 1.0, 5.0, ':penis', 'SUB']
# [4, 0, 0.0, 0.0, ':preputial gland', 'SUB']
# [1, 0, 0.147, 38.1024, ':creatinine', 'SUB']
# [1, 0, 0.0, 0.0, ':vaginal opening', 'MGR']
# [4, 1, 1.594, 510.5769666666667, ':intestine large', 'SUB']
# [1, 1, 1.0, 2200.0, ':lactic acid dehydrogenase (ldh)', 'SUB']
# [6, 4, 4.443, 23976.55076087333, ':liver', 'SUB']
# [2, 1, 0.8839999999999999, 3780.0384, ':erythrocyte (rbc) count differential', 'SUB']
# [1, 1, 1.0, 240.0, ':eosinophils', 'SUB']
# [2, 1, 1.354, 838.6818000000001, ':cholesterol', 'SUB']
# [3, 3, 2.777, 4622.779, ':estrous cycle', 'SUB']
# [2, 0, 0.0, 0.0, ':birth index', 'MGR']
# [4, 1, 1.188, 925.7333333333333, ':eye', 'SUB']
# [5, 2, 2.9939999999999998, 7648.678966666667, ':stomach', 'SUB']
# [4, 0, 0.083, 9.628, ':pituitary gland', 'SUB']
# [1, 0, 0.273, 150.15, ':triglycerides', 'SUB']
# [1, 0, 0.0, 0.0, ':oviduct', 'MGR']
# [2, 2, 1.737, 2812.6866666666665, ':albumin', 'SUB']
# [4, 0, 0.456, 5951.028000000001, ':thymus', 'SUB']
# [2, 0, 0.316, 120.54360000000001, ':ph', 'SUB']
# [3, 0, 0.103, 25.75, ':skin', 'SUB']
# [2, 0, 0.0, 0.0, ':glucose', 'SUB']
# [2, 1, 1.2730000000000001, 723.9485, ':sorbitol dehydrogenase', 'SUB']
# [1, 0, 0.354, 2420.3688, ':creatine phosphokinase', 'SUB']
# [2, 2, 2.0, 483.33333333333337, ':monocytes', 'SUB']
# [2, 0, 0.284, 161.88, ':gestational length', 'REP']
# [2, 0, 0.087, 76.125, ':live fetuses', 'MGR']
# [3, 1, 1.0, 101.99999999999999, ':tongue', 'SUB']
# [3, 0, 0.0, 0.0, ':mammary gland', 'SUB']
# [3, 0, 0.424, 1090.2205999999999, ':litter viability other', 'REP']
# [3, 0, 0.228, 542.71482, ':urinary bladder', 'SUB']
# [5, 2, 2.034, 4046.277066666667, ':bone', 'SUB']
# [3, 0, 0.0, 0.0, ':gestation index', 'REP']
# [3, 0, 0.0, 0.0, ':corpora lutea', 'REP']
# [1, 1, 1.0, 27570.0, ':lymphocyte', 'SUB']
# [3, 1, 1.0, 875.0, ':pregnancy index', 'REP']
# [3, 0, 0.0, 0.0, ':premature delivery', 'REP']
# [3, 0, 0.504, 2206.9943, ':heart', 'SUB']
# [2, 2, 2.0, 162.71333333333334, ':globulins', 'SUB']
# [4, 0, 0.545, 3106.8358333333335, ':brain', 'SUB']
# [3, 0, 0.0, 0.0, ':nerve', 'SUB']
# [3, 0, 0.0, 0.0, ':preimplantation loss', 'REP']
# [2, 2, 1.576, 4743.4, ':hemoglobin (hgb)', 'SUB']
# [1, 1, 0.645, 1819.8675, ':sperm measure', 'MGR']
# [3, 0, 0.5630000000000001, 89.877, ':trachea', 'SUB']
# [6, 2, 2.789, 18366.5945, ':clinical signs', 'SUB']
# [1, 1, 1.0, 577.5, ':sodium', 'SUB']
# [4, 0, 0.5269999999999999, 871.30475, ':adrenal gland', 'SUB']
# [3, 0, 0.0, 0.0, ':salivary glands', 'SUB']
# [2, 1, 1.487, 405.14674999999994, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [3, 0, 0.0, 0.0, ':harderian gland', 'SUB']
# [5, 0, 0.357, 2051.694, ':ovary', 'SUB']
# [1, 0, 0.0, 0.0, ':nipple development', 'MGR']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [2, 0, 0.0, 0.0, ':appearance and color', 'SUB']
# [4, 0, 0.0, 0.0, ':vagina', 'SUB']
# [1, 0, 0.0, 0.0, ':cervix', 'MGR']
# [4, 0, 0.0, 0.0, ':spinal cord', 'SUB']
# [3, 0, 0.0, 0.0, ':skeletal muscle', 'SUB']
# [4, 2, 1.871, 2689.0856875, ':nose', 'SUB']
# [3, 0, 0.164, 37.2685, ':intestine small', 'SUB']
# [2, 0, 0.516, 190.28164, ':protein', 'SUB']
# [4, 1, 1.134, 366.5666666666666, ':lymph node', 'SUB']
# [1, 0, 0.0, 0.0, ':coagulating gland', 'MGR']
# [3, 0, 0.0, 0.0, ':all gross anomalies', 'REP']
# [2, 0, 0.424, 2018.2399999999998, ':mating', 'REP']
# [2, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [2, 2, 1.576, 11994.6192, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [1, 1, 1.0, 1100.0, ':bilirubin', 'SUB']
# [1, 0, 0.436, 121.35333333333332, ':platelet', 'SUB']
# [5, 1, 1.246, 794.93465, ':epididymis', 'SUB']
# [3, 0, 0.5850000000000001, 38.8773, ':larynx', 'SUB']
# [1, 1, 1.0, 216.0, ':diaphragm', 'DEV']
# [1, 0, 0.0, 0.0, ':parathyroid', 'SUB']
# [3, 0, 0.0, 0.0, ':sex ratio', 'REP']
# [1, 1, 1.0, 258.5, ':placenta', 'DEV']
# [5, 5, 5.0, 2207.3333333333335, ':water consumption', 'SUB']
# [1, 0, 0.264, 880.0000000000001, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [4, 0, 0.933, 16295.191792857144, ':testes', 'SUB']
# [1, 1, 1.0, 6424.0, ':gamma glutamyl transpeptides (gtp)', 'SUB']
# [4, 1, 1.378, 5894.569428571428, ':lung', 'SUB']
# [1, 0, 0.0, 0.0, ':preputial separation', 'MGR']
# [4, 0, 0.25, 1550.0159999999998, ':seminal vesicle', 'SUB']
# [2, 1, 0.636, 4990.268, ':hematocrit (hct)', 'SUB']
# [3, 0, 0.44699999999999995, 902.2266095238095, ':thyroid gland', 'SUB']
# [1, 0, 0.0, 0.0, ':trunk', 'DEV']
# [3, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [2, 0, 0.0, 0.0, ':offspring survival early other', 'MGR']
# [2, 0, 0.0, 0.0, ':ear', 'SUB']
# [2, 0, 0.0, 0.0, ':dead fetuses', 'MGR']
# [1, 0, 0.0, 0.0, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [3, 0, 0.0, 0.0, ':parathyroid gland', 'SUB']
# [2, 0, 0.0, 0.0, ':dystocia', 'MGR']
# [1, 1, 1.0, 7324.0, ':neutrophils', 'SUB']
# [1, 1, 1.0, 83.33333333333334, ':luteinizing hormone (lh)', 'CHR']
# [5, 5, 4.161, 50509.20678438095, ':body weight', 'SUB']
# [3, 0, 0.624, 4976.054666666667, ':bone marrow', 'SUB']
# [2, 0, 0.069, 28.092857142857145, ':resorptions', 'MGR']
# [1, 1, 1.0, 1916.6666666666667, ':blood', 'CHR']
# [1, 0, 0.293, 32.9625, ':reticulocyte', 'SUB']
# [4, 4, 2.851, 23790.71161752381, ':kidney', 'SUB']
# [3, 0, 0.0, 0.0, ':gallbladder', 'SUB']
# [1, 0, 0.177, 1582.6614299999999, ':lactation index', 'MGR']
# [2, 0, 0.074, 112.05714285714285, ':implantations', 'MGR']
# [1, 0, 0.0, 0.0, ':precoital interval', 'MGR']
# [2, 0, 0.528, 5133.428571428572, ':volume', 'SUB']
# [3, 1, 1.332, 3751.5947523809527, ':urea nitrogen', 'SUB']
# [3, 0, 0.484, 2739.649066666667, ':pancreas', 'SUB']
# [1, 0, 0.177, 1582.6614299999999, ':viability index', 'MGR']
# [2, 2, 2.0, 44.44571428571429, ':calcium', 'SUB']
# [1, 1, 1.0, 25.92, ':lipids', 'SUB']
# [1, 1, 1.0, 83.33333333333334, ':follicle stimulating hormone (fsh)', 'CHR']
# [1, 1, 1.0, 4928.0, ':glutamate dehydrogenase', 'SUB']
# [3, 2, 1.712, 4064.8386666666665, ':leukocyte (wbc) count differential', 'SUB']
# [4, 0, 0.915, 5883.995466666667, ':spleen', 'SUB']
# [2, 0, 0.074, 112.05714285714285, ':aborted', 'MGR']
# [2, 0, 0.0, 0.0, ':litter size', 'MGR']
# [2, 0, 0.0, 0.0, ':pharynx', 'SUB']
# ...
# [1, 1, 1.0, 52.5, ':anemia', 'CHR']
# [2, 0, 0.214, 17.12, ':skin', 'SUB']
# [2, 1, 1.0, 7.0, ':glucose', 'SUB']
# [1, 0, 0.0, 0.0, ':sorbitol dehydrogenase', 'SUB']
# [1, 0, 0.0, 0.0, ':creatine phosphokinase', 'SUB']
# [1, 1, 1.0, 8.4, ':monocytes', 'SUB']
# [1, 0, 0.0, 0.0, ':gestational length', 'MGR']
# [2, 0, 0.37, 712.25, ':live fetuses', 'MGR']
# [2, 0, 0.0, 0.0, ':tongue', 'SUB']
# [2, 0, 0.267, 10.68, ':mammary gland', 'SUB']
# [1, 1, 1.0, 52.5, ':potassium', 'CHR']
# [2, 0, 0.0, 0.0, ':litter viability other', 'MGR']
# [2, 0, 0.305, 29.036, ':urinary bladder', 'SUB']
# [3, 1, 1.0, 2955.0, ':bone', 'SUB']
# [2, 0, 0.0, 0.0, ':gestation index', 'MGR']
# [2, 0, 0.0, 0.0, ':corpora lutea', 'MGR']
# [2, 2, 2.0, 315.4, ':lymphocyte', 'SUB']
# [2, 0, 0.0, 0.0, ':premature delivery', 'MGR']
# [1, 0, 0.0, 0.0, ':pregnancy index', 'MGR']
# [2, 0, 0.226, 45.2, ':heart', 'SUB']
# [2, 2, 2.0, 502.5, ':globulins', 'SUB']
# [3, 1, 1.757, 620.5725, ':brain', 'SUB']
# [2, 0, 0.0, 0.0, ':nerve', 'SUB']
# [2, 0, 0.0, 0.0, ':preimplantation loss', 'MGR']
# [2, 2, 2.0, 170.9, ':hemoglobin (hgb)', 'SUB']
# [1, 1, 1.0, 20.0, ':sperm measure', 'SUB']
# [2, 0, 0.0, 0.0, ':trachea', 'SUB']
# [4, 2, 1.594, 1832.5915, ':clinical signs', 'SUB']
# [1, 1, 1.0, 52.5, ':sodium', 'CHR']
# [3, 0, 0.0, 0.0, ':adrenal gland', 'SUB']
# [2, 0, 0.323, 2.7132, ':salivary glands', 'SUB']
# [1, 1, 1.0, 52.5, ':phosphorus', 'CHR']
# [2, 2, 1.5, 100.0, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [2, 1, 0.5, 12.5, ':harderian gland', 'SUB']
# [3, 1, 0.745, 221.2727, ':ovary', 'SUB']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [2, 0, 0.0, 0.0, ':appearance and color', 'SUB']
# [3, 0, 0.0, 0.0, ':vagina', 'SUB']
# [3, 0, 0.0, 0.0, ':spinal cord', 'SUB']
# [2, 0, 0.0, 0.0, ':skeletal muscle', 'SUB']
# [2, 0, 0.0, 0.0, ':nose', 'SUB']
# [2, 0, 0.0, 0.0, ':intestine small', 'SUB']
# [2, 1, 1.452, 338.42, ':protein', 'SUB']
# [2, 0, 0.0, 0.0, ':lymph node', 'SUB']
# [2, 0, 0.0, 0.0, ':all gross anomalies', 'MGR']
# [1, 0, 0.0, 0.0, ':mating', 'MGR']
# [2, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [2, 1, 1.0, 14.0, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [1, 0, 0.417, 3.5028, ':platelet', 'SUB']
# [3, 1, 0.548, 59.403200000000005, ':epididymis', 'SUB']
# [2, 0, 0.0, 0.0, ':larynx', 'SUB']
# [1, 1, 1.0, 17.5, ':ketones', 'CHR']
# [1, 1, 1.0, 630.0, ':diaphragm', 'DEV']
# [1, 0, 0.0, 0.0, ':parathyroid', 'SUB']
# [2, 0, 0.0, 0.0, ':sex ratio', 'MGR']
# [2, 2, 2.0, 110.89999999999999, ':water consumption', 'SUB']
# [3, 2, 2.6310000000000002, 15640.060000000001, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [1, 1, 1.0, 125.0, ':bile duct', 'CHR']
# [2, 2, 2.0, 78.3, ':thyroxine (t4)', 'SUB']
# [4, 1, 1.6500000000000001, 16838.169850000002, ':testes', 'SUB']
# [5, 2, 2.7319999999999998, 2067.94605, ':lung', 'SUB']
# [4, 0, 0.0, 0.0, ':seminal vesicle', 'SUB']
# [3, 2, 2.5, 17136.3, ':hematocrit (hct)', 'SUB']
# [3, 0, 0.7969999999999999, 797.086773, ':thyroid gland', 'SUB']
# [1, 0, 0.115, 66.24000000000001, ':trunk', 'DEV']
# [2, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [2, 0, 0.0, 0.0, ':offspring survival early other', 'MGR']
# [2, 0, 0.0, 0.0, ':ear', 'SUB']
# [2, 1, 1.537, 1650.64, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [2, 0, 0.115, 37.260000000000005, ':dead fetuses', 'MGR']
# [2, 0, 0.177, 198.24, ':parathyroid gland', 'SUB']
# [2, 0, 0.0, 0.0, ':dystocia', 'MGR']
# [1, 1, 1.0, 2720.0, ':nucleated red blood cell (nrbc)', 'SUB']
# [3, 3, 3.0, 9720.21, ':neutrophils', 'SUB']
# [1, 1, 1.0, 300.0, ':methemoglobin', 'SUB']
# [5, 5, 4.821, 42475.30541666667, ':body weight', 'SUB']
# [3, 0, 0.305, 281.45, ':bone marrow', 'SUB']
# [2, 0, 0.345, 583.74, ':resorptions', 'MGR']
# [2, 2, 2.0, 3300.0, ':blood', 'SUB']
# [2, 2, 2.0, 3583.8, ':reticulocyte', 'SUB']
# [5, 3, 3.52, 12038.66702, ':kidney', 'SUB']
# [3, 1, 1.22, 10343.8, ':gallbladder', 'SUB']
# [1, 0, 0.171, 38.475, ':lactation index', 'MGR']
# [2, 0, 0.0, 0.0, ':implantations', 'MGR']
# [1, 0, 0.0, 0.0, ':precoital interval', 'MGR']
# [2, 0, 0.375, 55.5, ':volume', 'SUB']
# [1, 1, 1.0, 6.25, ':non-protein sulfhydryl (npsh)', 'SUB']
# [2, 2, 2.0, 33.3, ':triiodothyronine (t3)', 'SUB']
# [3, 2, 2.217, 7203.761, ':urea nitrogen', 'SUB']
# [2, 0, 0.189, 85.86, ':pancreas', 'SUB']
# [1, 1, 1.0, 44.495, ':myeloid/erythroid (m:e) ratio', 'SUB']
# [1, 0, 0.342, 80.7975, ':viability index', 'MGR']
# [2, 2, 2.0, 201.15, ':calcium', 'SUB']
# [3, 1, 1.8010000000000002, 7242.52587, ':leukocyte (wbc) count differential', 'SUB']
# [1, 1, 1.0, 44.495, ':uric acid', 'SUB']
# [1, 1, 1.0, 133.65, ':flouride', 'SUB']
# [4, 1, 1.45, 1276.2826, ':spleen', 'SUB']
# [2, 0, 0.218, 2454.68, ':aborted', 'MGR']
# [2, 0, 0.457, 806.6700000000001, ':litter size', 'MGR']
# [2, 0, 0.0, 0.0, ':pharynx', 'SUB']
# [2, 2, 2.0, 7137.5, ':albumin-globulin ratio', 'SUB']
# [1, 0, 0.0, 0.0, ':lacrimal gland', 'SUB']
# [4, 0, 0.084, 33.6, ':prostate', 'SUB']
# [5, 1, 2.079, 13059.271955000002, ':food consumption', 'SUB']
# [1, 0, 0.342, 677.1600000000001, ':fertility', 'MGR']
# [5, 0, 0.23, 298.08000000000004, ':uterus', 'SUB']
# [4, 0, 0.093, 188.325, ':full gross necropsy', 'SUB']
# [1, 0, 0.0, 0.0, ':bile acids', 'SUB']
# [2, 0, 0.171, 292.41, ':pregnancy', 'MGR']
# [2, 0, 0.78, 10266.3431, ':specific gravity/osmolality', 'SUB']
# [2, 1, 1.474, 2021.7093, ':alkaline phosphatase (alp/alk)', 'SUB']
# [2, 0, 0.28600000000000003, 337.365, ':reproductive performance other', 'MGR']
# [5, 2, 1.754, 12831.110250000002, ':mortality', 'SUB']
# [2, 2, 2.0, 58.0, ':oral mucosa', 'SUB']
# [2, 1, 1.0, 162.0, ':general', 'SAC']
# [4, 3, 3.0, 4038.305, ':[other]', 'SUB']
# [2, 0, 0.345, 1164.3749999999998, ':postimplantation loss', 'MGR']
# [2, 0, 0.237, 77.26199999999999, ':esophagus', 'SUB']
# [1, 1, 1.0, 90.0, ':aspartate aminotransferase (ast/sgot)', 'CHR']
# [2, 0, 0.0, 0.0, ':preputial gland', 'SUB']
# [3, 2, 1.775, 3619.23125, ':creatinine', 'SUB']
# [4, 1, 1.0, 285.0, ':intestine large', 'SUB']
# [1, 1, 1.0, 44.495, ':lactic acid dehydrogenase (ldh)', 'SUB']
# [4, 2, 2.644, 18062.14032, ':liver', 'SUB']
# [4, 3, 3.036, 17675.23, ':erythrocyte (rbc) count differential', 'SUB']
# [1, 1, 1.0, 720.0, ':eosinophils', 'SUB']
# [3, 1, 1.942, 9440.232, ':cholesterol', 'SUB']
# [2, 1, 1.0, 20000.0, ':blood clotting', 'SUB']
# [2, 0, 0.0, 0.0, ':birth index', 'MGR']
# [2, 2, 2.0, 6160.0, ':estrous cycle', 'SUB']
# [4, 1, 1.177, 253.14, ':eye', 'SUB']
# [1, 1, 1.0, 67.5, ':gamma glutamyl transferase (ggt)', 'CHR']
# [3, 0, 0.093, 1.674, ':pituitary gland', 'SUB']
# [5, 2, 2.586, 12532.442, ':stomach', 'SUB']
# [3, 2, 2.203, 9530.0126875, ':triglycerides', 'SUB']
# [3, 2, 1.834, 2653.6561, ':albumin', 'SUB']
# [4, 1, 1.921, 1740.5581499999998, ':thymus', 'SUB']
# [2, 0, 0.175, 87.5, ':ph', 'SUB']
# [1, 1, 1.0, 167.5, ':anemia', 'CHR']
# [3, 0, 0.737, 343.371, ':skin', 'SUB']
# [3, 0, 0.683, 1116.88715, ':glucose', 'SUB']
# [1, 1, 1.0, 3200.0, ':anisocytosis', 'DEV']
# [1, 0, 0.0, 0.0, ':sorbitol dehydrogenase', 'SUB']
# [1, 1, 1.0, 3200.0, ':hypochromia', 'DEV']
# [1, 0, 0.0, 0.0, ':creatine phosphokinase', 'SUB']
# [1, 1, 1.0, 730.8, ':monocytes', 'SUB']
# [1, 0, 0.171, 292.41, ':gestational length', 'MGR']
# [2, 0, 0.333, 4345.983, ':live fetuses', 'MGR']
# [2, 0, 0.0, 0.0, ':tongue', 'SUB']
# [2, 0, 0.0, 0.0, ':mammary gland', 'SUB']
# [2, 1, 1.0, 72.5, ':potassium', 'SAC']
# [2, 0, 0.316, 564.06, ':litter viability other', 'MGR']
# [3, 0, 0.179, 12.3507, ':urinary bladder', 'SUB']
# [3, 0, 0.68, 2348.46, ':bone', 'SUB']
# [2, 0, 0.0, 0.0, ':gestation index', 'MGR']
# [2, 0, 0.0, 0.0, ':corpora lutea', 'MGR']
# [3, 3, 3.0, 10426.345, ':lymphocyte', 'SUB']
# [2, 0, 0.218, 2183.924, ':premature delivery', 'MGR']
# [1, 0, 0.0, 0.0, ':pregnancy index', 'MGR']
# [3, 0, 0.358, 1845.10455, ':heart', 'SUB']
# [3, 3, 3.0, 15528.65, ':globulins', 'SUB']
# [5, 2, 3.109, 7438.17215, ':brain', 'SUB']
# [3, 0, 0.084, 16.8, ':nerve', 'SUB']
# [2, 0, 0.0, 0.0, ':preimplantation loss', 'MGR']
# [4, 3, 3.5, 16886.8, ':hemoglobin (hgb)', 'SUB']
# [1, 1, 1.0, 1161.0, ':sperm measure', 'SUB']
# [3, 0, 0.096, 86.4, ':trachea', 'SUB']
# [5, 3, 3.2960000000000003, 24975.191333333336, ':clinical signs', 'SUB']
# [2, 1, 1.0, 67.5, ':sodium', 'SAC']
# [4, 0, 0.263, 1004.4200000000001, ':adrenal gland', 'SUB']
# [2, 0, 0.096, 1.0368000000000002, ':salivary glands', 'SUB']
# [2, 2, 2.0, 14107.5, ':phosphorus', 'SAC']
# [3, 2, 2.668, 2814.5464, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [2, 0, 0.0, 0.0, ':harderian gland', 'SUB']
# [4, 1, 0.848, 6784.9397, ':ovary', 'SUB']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [2, 0, 0.135, 247.05, ':appearance and color', 'SUB']
# [3, 0, 0.0, 0.0, ':vagina', 'SUB']
# [4, 0, 0.0, 0.0, ':spinal cord', 'SUB']
# [2, 0, 0.0, 0.0, ':skeletal muscle', 'SUB']
# [2, 0, 0.444, 187.38467666666668, ':nose', 'SUB']
# [4, 1, 1.26, 608.12, ':intestine small', 'SUB']
# [3, 1, 1.472, 11127.4944, ':protein', 'SUB']
# [1, 1, 1.0, 576.0, ':blood vessel', 'DEV']
# [3, 0, 0.483, 689.4688, ':lymph node', 'SUB']
# [2, 0, 0.0, 0.0, ':all gross anomalies', 'MGR']
# [1, 0, 0.0, 0.0, ':mating', 'MGR']
# [1, 1, 1.0, 720.0, ':chloride', 'CHR']
# [2, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [1, 1, 1.0, 18.0, ':bilirubin', 'CHR']
# [4, 3, 3.6310000000000002, 16677.8, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [2, 1, 0.704, 1939.1328, ':platelet', 'SUB']
# [4, 0, 0.44800000000000006, 2652.6716, ':epididymis', 'SUB']
# [2, 0, 0.096, 155.52, ':larynx', 'SUB']
# [1, 1, 1.0, 22.5, ':ketones', 'CHR']
# [1, 1, 1.0, 810.0, ':diaphragm', 'DEV']
# [1, 0, 0.0, 0.0, ':parathyroid', 'SUB']
# [2, 0, 0.0, 0.0, ':sex ratio', 'MGR']
# [4, 4, 4.0, 6077.995, ':water consumption', 'SUB']
# [1, 1, 1.0, 3200.0, ':lipids, total', 'DEV']
# [2, 2, 2.0, 17515.0, ':mean corpuscular hemoglobin (mch)', 'SUB']
# [1, 1, 1.0, 112.5, ':bile duct', 'CHR']
# [4, 2, 2.238, 22208.2628, ':testes', 'SUB']
# [1, 1, 1.0, 432.0, ':gamma glutamyl transpeptides (gtp)', 'SUB']
# [5, 2, 2.735, 1655.0055, ':lung', 'SUB']
# [4, 0, 0.135, 16.200000000000003, ':seminal vesicle', 'SUB']
# [3, 3, 3.0, 20484.0, ':hematocrit (hct)', 'SUB']
# [3, 0, 0.641, 523.10248, ':thyroid gland', 'SUB']
# [1, 0, 0.109, 55.808, ':trunk', 'DEV']
# [2, 0, 0.0, 0.0, ':clitoral gland', 'SUB']
# [2, 0, 0.0, 0.0, ':offspring survival early other', 'MGR']
# [2, 0, 0.0, 0.0, ':ear', 'SUB']
# [2, 0, 0.0, 0.0, ':dead fetuses', 'MGR']
# [1, 1, 1.0, 2872.0, ':mean corpuscular hemoglobin concentration (mchc)', 'SUB']
# [2, 0, 0.138, 88.32000000000001, ':parathyroid gland', 'SUB']
# [2, 0, 0.0, 0.0, ':dystocia', 'MGR']
# [1, 1, 1.0, 2440.0, ':nucleated red blood cell (nrbc)', 'SUB']
# [2, 2, 2.0, 8569.18, ':neutrophils', 'SUB']
# [1, 1, 1.0, 270.0, ':methemoglobin', 'SUB']
# [5, 5, 4.5729999999999995, 25589.6077, ':body weight', 'SUB']
# [3, 0, 0.328, 367.05, ':bone marrow', 'SUB']
# [2, 0, 0.219, 266.30400000000003, ':resorptions', 'MGR']
# [1, 1, 1.0, 2250.0, ':blood', 'SUB']
# [1, 1, 1.0, 3512.0, ':reticulocyte', 'SUB']
# [4, 3, 2.923, 16895.602675000002, ':kidney', 'SUB']
# [2, 0, 0.0, 0.0, ':gallbladder', 'SUB']
# [1, 0, 0.257, 51.4, ':lactation index', 'MGR']
# [2, 0, 0.0, 0.0, ':implantations', 'MGR']
# [1, 0, 0.0, 0.0, ':precoital interval', 'MGR']
# [2, 1, 0.872, 1717.289, ':volume', 'SUB']
# [1, 1, 1.0, 5.625, ':non-protein sulfhydryl (npsh)', 'SUB']
# [3, 3, 2.628, 8763.68, ':urea nitrogen', 'SUB']
# [2, 0, 0.329, 574.07, ':pancreas', 'SUB']
# [1, 0, 0.257, 51.4, ':viability index', 'MGR']
# [1, 1, 1.0, 2368.8, ':calcium', 'SUB']
# [1, 1, 1.0, 2250.0, ':lipids', 'SUB']
# [1, 1, 1.0, 2250.0, ':glutamate dehydrogenase', 'SUB']
# [3, 2, 1.9009999999999998, 8862.76, ':leukocyte (wbc) count differential', 'SUB']
# [1, 1, 1.0, 118.8, ':flouride', 'SUB']
# [4, 1, 1.5799999999999998, 2535.495, ':spleen', 'SUB']
# [2, 0, 0.109, 122.08, ':aborted', 'MGR']
# [2, 1, 0.623, 1006.16, ':litter size', 'MGR']
# [2, 0, 0.0, 0.0, ':pharynx', 'SUB']
# [1, 1, 1.0, 6363.0, ':albumin-globulin ratio', 'SUB']
# [1, 0, 0.0, 0.0, ':lacrimal gland', 'SUB']
# [4, 0, 0.135, 16.200000000000003, ':prostate', 'SUB']
# [5, 1, 2.135, 10746.55924, ':food consumption', 'SUB']
# [1, 1, 0.514, 904.64, ':fertility', 'MGR']
# [1, 1, 1.0, 120.0, ':cholinesterase', 'SUB']
# [5, 0, 0.692, 1431.035, ':uterus', 'SUB']
# [4, 0, 0.383, 703.1600000000001, ':full gross necropsy', 'SUB']
# [1, 0, 0.0, 0.0, ':bile acids', 'SUB']
# [2, 0, 0.257, 390.64, ':pregnancy', 'MGR']
# [2, 1, 1.039, 2003.1336, ':specific gravity/osmolality', 'SUB']
# [1, 1, 0.707, 1863.0864, ':alkaline phosphatase (alp/alk)', 'SUB']
# [2, 0, 0.257, 400.92, ':reproductive performance other', 'MGR']
# [5, 0, 1.423, 2436.376, ':mortality', 'SUB']
# [2, 1, 1.0, 360.0, ':general', 'SAC']
# [4, 3, 3.0, 3312.5, ':[other]', 'SUB']
# [2, 0, 0.244, 410.408, ':postimplantation loss', 'MGR']
# [2, 0, 0.0, 0.0, ':esophagus', 'SUB']
# [1, 1, 1.0, 432.0, ':aspartate aminotransferase (ast/sgot)', 'SUB']
# [2, 0, 0.0, 0.0, ':preputial gland', 'SUB']
# [3, 2, 1.776, 3633.517, ':creatinine', 'SUB']
# [4, 1, 1.09, 472.5, ':intestine large', 'SUB']
# [4, 4, 3.203, 29912.723865, ':liver', 'SUB']
# [4, 4, 3.628, 20676.144, ':erythrocyte (rbc) count differential', 'SUB']
# [1, 1, 1.0, 640.0, ':eosinophils', 'SUB']
# [3, 3, 2.577, 11928.871, ':cholesterol', 'SUB']
# [2, 1, 1.0, 2250.0, ':blood clotting', 'SUB']
# [2, 0, 0.0, 0.0, ':birth index', 'MGR']
# [2, 2, 2.0, 5525.0, ':estrous cycle', 'SUB']
# [3, 0, 0.138, 88.32000000000001, ':eye', 'SUB']
# [5, 2, 2.574, 2872.84, ':stomach', 'SUB']
# [3, 0, 0.0, 0.0, ':pituitary gland', 'SUB']
# [3, 2, 2.32, 8569.018, ':triglycerides', 'SUB']
# [3, 2, 1.759, 2429.5771999999997, ':albumin', 'SUB']
# [4, 1, 1.7160000000000002, 1138.8647999999998, ':thymus', 'SUB']
# [2, 0, 0.163, 70.416, ':ph', 'SUB']
# [3, 0, 0.0, 0.0, ':skin', 'SUB']
# [3, 0, 0.355, 102.664875, ':glucose', 'SUB']
# [1, 1, 1.0, 2880.0, ':anisocytosis', 'DEV']
# [1, 0, 0.0, 0.0, ':sorbitol dehydrogenase', 'SUB']
# [1, 1, 1.0, 2880.0, ':hypochromia', 'DEV']
# [1, 0, 0.298, 128.736, ':creatine phosphokinase', 'SUB']
# [1, 1, 1.0, 640.0, ':monocytes', 'SUB']
# [1, 0, 0.257, 390.64, ':gestational length', 'MGR']
# [2, 0, 0.109, 55.808, ':live fetuses', 'MGR']
# [2, 0, 0.0, 0.0, ':tongue', 'SUB']
# [2, 0, 0.0, 0.0, ':mammary gland', 'SUB']
# [2, 0, 0.229, 61.830000000000005, ':litter viability other', 'MGR']
# [2, 1, 1.0, 2250.0, ':potassium', 'SUB']
# [3, 0, 0.325, 245.68800000000002, ':urinary bladder', 'SUB']
# [3, 0, 0.794, 859.576, ':bone', 'SUB']
# [2, 0, 0.0, 0.0, ':gestation index', 'MGR']
# [2, 0, 0.0, 0.0, ':corpora lutea', 'MGR']
# [2, 2, 2.0, 9209.0, ':lymphocyte', 'SUB']
# [2, 0, 0.109, 1.744, ':premature delivery', 'MGR']
# [1, 0, 0.0, 0.0, ':pregnancy index', 'MGR']
# [3, 0, 0.544, 3705.8744, ':heart', 'SUB']
# [3, 3, 3.0, 13608.099999999999, ':globulins', 'SUB']
# [4, 2, 2.544, 10946.7364, ':brain', 'SUB']
# [3, 0, 0.135, 0.81, ':nerve', 'SUB']
# [2, 0, 0.0, 0.0, ':preimplantation loss', 'MGR']
# [4, 4, 4.0, 22572.45, ':hemoglobin (hgb)', 'SUB']
# [1, 1, 1.0, 1035.0, ':sperm measure', 'SUB']
# [3, 0, 0.101, 80.80000000000001, ':trachea', 'SUB']
# [5, 3, 3.069, 18468.048, ':clinical signs', 'SUB']
# [1, 0, 0.0, 0.0, ':sodium', 'SAC']
# [4, 0, 0.21900000000000003, 91.965, ':adrenal gland', 'SUB']
# [2, 0, 0.0, 0.0, ':salivary glands', 'SUB']
# [2, 2, 2.0, 10981.0, ':phosphorus', 'SAC']
# [2, 0, 0.0, 0.0, ':harderian gland', 'SUB']
# [4, 1, 1.2570000000000001, 11743.872, ':ovary', 'SUB']
# [1, 1, 0.53, 98.79200000000002, ':alanine aminotransferase (alt/sgpt)', 'SUB']
# [1, 0, 0.0, 0.0, ':other', 'DEV']
# [2, 0, 0.0, 0.0, ':appearance and color', 'SUB']
# [3, 0, 0.0, 0.0, ':vagina', 'SUB']
# [4, 0, 0.15, 18.0, ':spinal cord', 'SUB']
# [2, 0, 0.414, 49.68, ':skeletal muscle', 'SUB']
# [2, 0, 0.373, 111.0445, ':nose', 'SUB']
# [4, 1, 1.179, 753.3, ':intestine small', 'SUB']
# [3, 1, 1.627, 11635.107100000001, ':protein', 'SUB']
# [1, 1, 1.0, 512.0, ':blood vessel', 'DEV']
# [3, 0, 0.55, 612.0436, ':lymph node', 'SUB']
# [2, 0, 0.0, 0.0, ':all gross anomalies', 'MGR']
# [1, 0, 0.0, 0.0, ':mating', 'MGR']
# [1, 1, 1.0, 640.0, ':chloride', 'CHR']
# [2, 0, 0.0, 0.0, ':occult blood', 'SUB']
# [4, 4, 4.0, 18752.45, ':mean corpuscular (cell) volume (mcv)', 'SUB']
# [2, 1, 1.0, 2463.8, ':platelet', 'SUB']
# [4, 0, 0.5820000000000001, 2913.615, ':epididymis', 'SUB']
# [2, 0, 0.101, 145.44, ':larynx', 'SUB']
# [1, 1, 1.0, 360.0, ':diaphragm', 'DEV']
# [1, 0, 0.0, 0.0, ':parathyroid', 'SUB']
# [2, 0, 0.0, 0.0, ':sex ratio', 'MGR']
# [4, 4, 4.0, 3592.9, ':water consumption', 'SUB']
# [1, 1, 1.0, 2880.0, ':lipids, total', 'DEV']

# %% [markdown]
# # Usefull links and websites:
# https://www.chemspider.com/ not used that much
#
# https://comptox.epa.gov/genra/DTXCID50778 The code here 100% relies on this software, the comptox genRA package, generalized read-across
#
# https://cfpub.epa.gov/ecotox/explore.cfm?sub=Effects don't remember, but has been used
#
# https://comptox.epa.gov/dashboard/batch-search powerful database, has been used to find details
#
# https://sandbox.ntp.niehs.nih.gov/tox21-curve-visualization/ usefull database but not clear how I can use it for an index
#
# https://pubchem.ncbi.nlm.nih.gov/#query=50-00-0%20OR%207727-37-9%20OR%20124-38-9%20OR%20138-86-3%20OR%2010028-15-6&tab=compound contains a lot of chemical and physical data in general
#
# https://echa.europa.eu/information-on-chemicals/cl-inventory-database?p_p_id=dissclinventory_WAR_dissclinventoryportlet&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view handy lookup website for EU CLP regulation, starting point before finding MGR, DEV, SAC, CHR and SUB
#
# https://ice.ntp.niehs.nih.gov/Tools yet another usefull website but not used that much
#
# Cas No/chemical were interested in
# * 50-00-0 CH2O Formaldehyde
# * 7727-37-9 N2 Nitrogen
# * 124-38-9 CO2 Carbon Dioxide
# * 138-86-3 / 5989-59-8 C10H16 Limonene
# * 10028-15-6 O3 Ozone

# %%
from pivottablejs import pivot_ui

pivot_ui(target_DF)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
PVTable
# Out:
# Formula                              C10H16                             \
# Testgroup                               CHR  DEV    MGR  SAC       SUB
# Effectgroup
# :5' nucleotidase                        0.0  0.0  0.000  0.0  0.229991
# :[other]                                0.0  0.0  0.000  0.0  0.459982
# :aborted                                0.0  0.0  0.074  0.0  0.000000
# :adrenal gland                          0.0  0.0  0.000  0.0  0.170653
# :alanine aminotransferase (alt/sgpt)    0.0  0.0  0.000  0.0  0.367065
# ...                                     ...  ...    ...  ...       ...
# :vagina                                 0.0  0.0  0.000  0.0  0.271159
# :vaginal opening                        0.0  0.0  0.459  0.0  0.000000
# :viability index                        0.0  0.0  0.177  0.0  0.000000
# :volume                                 0.0  0.0  0.000  0.0  0.121435
# :water consumption                      0.0  0.0  0.000  0.0  0.000000
#
# Formula                              C10H16O2                     C8H14O  ...  \
# Testgroup                                 DEV  MGR  REP       SUB    CHR  ...
# Effectgroup                                                               ...
# :5' nucleotidase                          0.0  0.0  0.0  0.000000    NaN  ...
# :[other]                                  0.0  0.0  0.0  0.361795    NaN  ...
# :aborted                                  0.0  0.0  0.0  0.000000    NaN  ...
# :adrenal gland                            0.0  0.0  0.0  0.077967    NaN  ...
# :alanine aminotransferase (alt/sgpt)      0.0  0.0  0.0  0.054088    NaN  ...
# ...                                       ...  ...  ...       ...    ...  ...
# :vagina                                   0.0  0.0  0.0  0.180897    NaN  ...
# :vaginal opening                          0.0  0.0  0.0  0.000000    NaN  ...
# :viability index                          0.0  0.0  0.0  0.000000    NaN  ...
# :volume                                   0.0  0.0  0.0  0.061143    NaN  ...
# :water consumption                        0.0  0.0  0.0  0.361795    NaN  ...
#
# Formula                                    CO2   N2                    O3  \
# Testgroup                                  SUB  CHR  DEV  MGR    SUB  CHR
# Effectgroup
# :5' nucleotidase                      0.000000  0.0  0.0  0.0  0.250  0.0
# :[other]                              0.622278  0.0  0.0  0.0  0.250  0.0
# :aborted                              0.000000  0.0  0.0  0.0  0.000  0.0
# :adrenal gland                        0.054553  0.0  0.0  0.0  0.000  0.0
# :alanine aminotransferase (alt/sgpt)  0.553412  0.0  0.0  0.0  0.375  0.0
# ...                                        ...  ...  ...  ...    ...  ...
# :vagina                               0.000000  0.0  0.0  0.0  0.000  0.0
# :vaginal opening                      0.000000  0.0  0.0  0.0  0.000  0.0
# :viability index                      0.000000  0.0  0.0  1.0  0.000  0.0
# :volume                               0.077785  0.0  0.0  0.0  0.000  0.0
# :water consumption                    0.829703  0.0  0.0  0.0  0.500  0.0
#
# Formula
# Testgroup                             DEV     MGR  SAC       SUB
# Effectgroup
# :5' nucleotidase                      0.0  0.0000  0.0  0.000000
# :[other]                              0.0  1.0000  0.0  0.000000
# :aborted                              0.0  0.1112  0.0  0.000000
# :adrenal gland                        0.0  0.0000  0.0  0.058168
# :alanine aminotransferase (alt/sgpt)  0.0  0.0000  0.0  0.298267
# ...                                   ...     ...  ...       ...
# :vagina                               0.0  0.0000  0.0  0.000000
# :vaginal opening                      0.0  0.0000  0.0  0.000000
# :viability index                      0.0  0.0000  0.0  0.000000
# :volume                               0.0  0.0000  0.0  0.196576
# :water consumption                    0.0  0.0000  0.0  0.618812
#
# [173 rows x 38 columns]

# %%
df[df.Formula == "O3"]
# Out:
#     Formula   Name  total targets  positive targets  positive targets decimal  \
# 0        O3  Ozone              2                 0                     0.000
# 1        O3  Ozone              1                 1                     1.000
# 2        O3  Ozone              2                 0                     0.000
# 3        O3  Ozone              3                 0                     0.144
# 4        O3  Ozone              1                 0                     0.000
# ..      ...    ...            ...               ...                       ...
# 135      O3  Ozone              2                 2                     1.242
# 136      O3  Ozone              2                 2                     1.512
# 137      O3  Ozone              4                 0                     0.000
# 138      O3  Ozone              3                 3                     2.468
# 139      O3  Ozone              5                 1                     1.704
#
#      weighted and averaged limit [mg/kg/day]        Effectgroup Testgroup
# 0                                     0.0000         :sex ratio       MGR
# 1                                    68.7500         :bile duct       CHR
# 2                                     0.0000   :gestation index       MGR
# 3                                     8.0640   :salivary glands       SUB
# 4                                     0.0000           :oviduct       MGR
# ..                                       ...                ...       ...
# 135                                3111.5205     :urea nitrogen       SUB
# 136                                4915.1496     :triglycerides       SUB
# 137                                   0.0000   :seminal vesicle       SUB
# 138                                8901.3995  :hematocrit (hct)       SUB
# 139                                2927.7975             :brain       SUB
#
# [140 rows x 8 columns]

# %%
label = "genra_O3"
HID, effectLabels, targetLabels, md, chemName = computeHealthIndex(label)#Ozone
metaDataHID = metaDataGenEffects(effectLabels, HID)
metaDataHIDt = metaDataGenTargets(targetLabels,HID)
metaDataReport(effectLabels,metaDataHID,md,label)
TargetEffectLabels = TrackTargetEffectLabels(HID,TargetEffectLabels)
# Out:
#      preferred name          Ozone       Sodium nitrite    Barium metaborate  \
# 0        dsstox_sid  DTXSID0021098        DTXSID0020941        DTXSID1034347
# 1  molecular weight         47.997               68.995              222.940
# 2        similarity        1.00001  0.18181818181818182  0.18181818181818182
#
#     Trisodium arsenate       Silver nitrate Monosodium methanearsonate  \
# 0        DTXSID9039367        DTXSID3032042              DTXSID2025686
# 1              207.887              169.872                    161.951
# 2  0.18181818181818182  0.18181818181818182        0.13333333333333333
#
#   Potassium dichromate Trichloronitromethane Sodium dichromate dihydrate  \
# 0        DTXSID5025948         DTXSID0020315               DTXSID6032061
# 1              294.182               164.370                     297.995
# 2  0.13333333333333333   0.13333333333333333                       0.125
#
#   Sodium fluoroacetate Sodium trichloroacetate  \
# 0        DTXSID8024311           DTXSID6034924
# 1              100.024                 185.360
# 2                0.125                   0.125
#
#   Butanedioic acid, 2,3-dihydroxy- (2R,3R)-, sodium salt (1:2)  \
# 0                                      DTXSID2057861
# 1                                            194.050
# 2                                0.11764705882352941
#
#   Tetrakis(hydroxymethyl)phosphonium sulfate              Silica  \
# 0                              DTXSID0021331       DTXSID1029677
# 1                                    406.280              60.083
# 2                         0.1111111111111111  0.1111111111111111
#
#   Lithium hypochlorite 2-(Hydroxymethyl)-2-nitro-1,3-propanediol
# 0        DTXSID1034688                             DTXSID8027034
# 1               58.390                                   151.118
# 2   0.1111111111111111                       0.10526315789473684
# MGR - total targets: 55 - Targets positive: 12 - Total targets decimal: 8.50 - weighted and averaged limit 3469.12 [mg/kg/day]
# DEV - total targets: 48 - Targets positive: 23 - Total targets decimal: 23.50 - weighted and averaged limit 87704.35 [mg/kg/day]
# SAC - total targets: 74 - Targets positive: 18 - Total targets decimal: 17.10 - weighted and averaged limit 94654.44 [mg/kg/day]
# CHR - total targets: 78 - Targets positive: 24 - Total targets decimal: 27.83 - weighted and averaged limit 9685.57 [mg/kg/day]
# SUB - total targets: 92 - Targets positive: 32 - Total targets decimal: 33.75 - weighted and averaged limit 84568.61 [mg/kg/day]

# %%
columns[1]
# Out:
# 'Ozone'
